# %% [markdown]
# ## 03 Recommender

# %% [markdown]
# Project: Building a Personalised Playlist Generator for Spotify
# <br>
# Name: Syahiran Rafi

# %% [markdown]
# ---

# %% [markdown]
# ### Description

# %% [markdown]
# This notebook outlines the entire process of building the song recommender system.
#
# The user journey may be broken down into two main stages:
# 1. Choosing your favourite genre(s) to generate a list of random tracks (`generate_random_tracks_balanced`)
# 2. Choosing at least 3 songs from the randomly generated list to create your own personalist playlist of 15 songs (`generate_personalised_playlist`)

# %% [markdown]
# The following functions were created to support the above user journey:
# | Function                      | Description |
# |-------------------------------|-------------|
# | `top_subgenres`               |Generates a list of top sub-genres for a list of genres|
# | `generate_random_tracks`      |Generates a list of `n` random songs based on genre(s)|
# | `generate_random_tracks_balanced` |Generates a list of `n` random songs based on genre(s), with a balanced sample of genres if more than one genre is input|
# | `track_viewer`                |Formats the random list of songs into a more readable format for user studies|
# | `extract_genres`              |Reformats the genre strings `'pop,rock,dance'` into a list of genres `['pop', 'rock', 'dance']`|
# | `one_hot_encode_genres`       |Performs one hot encoding on `artist_genres` before building the `cosine_similarity` matrix|
# | `recommend_songs`             |Recommends top `n` songs for a single `track_name` and `artist_name` pair|
# | `generate_personalised_playlist` |Generates a personalised playlist of 15 songs, using the tracks selected from the randomly generated list|
# | `df_to_tuples`                |Reformats the result from `generate_personalised_playlist` into a list of `('track_name','artist_name')` tuples to input in the `generate_spotify_playlist` function|
# | `generate_spotify_playlist`   |Creates an actual Spotify playlist using Spotify API|

# %% [markdown]
# ---

# %% [markdown]
# ### 1. Import libraries

# %%
# Standard imports
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
import random

# Recommender
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import StandardScaler

# Spotify API
import spotipy
from spotipy.oauth2 import SpotifyOAuth
import pandas as pd
import socket
from http.server import HTTPServer, BaseHTTPRequestHandler

# %% [markdown]
# ### 2. Read relevant data sets into a data frame

# %% [markdown]
# Three main CSV files processed and exported from the earlier notebooks are exported into data frames for use within this notebook:
# 1. spotify-top-10k-processed.csv
# 2. spotify-40k-processed
# 3. genres-10k

# %% [markdown]
# The 10k data set is mainly used to generate random tracks for users based on genre(s) selected (`generate_random_tracks_balanced`).

# %%
tracks_10k_df = pd.read_csv("../data/spotify-top-10k-processed.csv")

# %%
tracks_10k_df
# Out:
#                                  track_uri  \
# 0     spotify:track:1xazlnvtthcdzt2ni1dtxo
# 1     spotify:track:6a8gbqilv8hbuw3c6uk9ph
# 2     spotify:track:70xtwbcvzcpaoddjftmcvi
# 3     spotify:track:1nxuwypjk5ko6dqj5t7bdu
# 4     spotify:track:72wztws6v7uu3amgmmekye
# ...                                    ...
# 8870  spotify:track:6puzxtihkv346yp89nzp9x
# 8871  spotify:track:3kcklokqqepvwxwljbgj5p
# 8872  spotify:track:5k9qrzjfdap5cxvdzai02f
# 8873  spotify:track:5ydecnawdmfbu4zl0ropah
# 8874  spotify:track:0zkbdrexkpnexhgqre9dxt
#
#                                              track_name  \
# 0               justified & ancient - stand by the jams
# 1                       i know you want me (calle ocho)
# 2                    from the bottom of my broken heart
# 3                      apeman - 2014 remastered version
# 4                    you can't always get what you want
# ...                                                 ...
# 8870                                      kernkraft 400
# 8871                       kernkraft 400 (a better day)
# 8872                       never say never - radio edit
# 8873  groovejet (if this ain't love) [feat. sophie e...
# 8874                                            lay low
#
#                                              artist_uri  \
# 0                 spotify:artist:6dyrdrlnzskavxyg5irvch
# 1                 spotify:artist:0tnoyisbd1xyrbk9myaseg
# 2                 spotify:artist:26dsoyclwsylmakd3tpor4
# 3                 spotify:artist:1sqrv42e4pjeyfphs0tk9e
# 4                 spotify:artist:22be4uq6banwshpvcdxlce
# ...                                                 ...
# 8870              spotify:artist:7vfpnlbcxbbfs4kfbulksl
# 8871  spotify:artist:0u6gtibw46tfx7koq6unjz, spotify...
# 8872              spotify:artist:1sczsjoyaihnnm9qlhzdnl
# 8873  spotify:artist:4bmymfwdu9zlcitrumrewb, spotify...
# 8874              spotify:artist:2o5jdhthvphrjdv3ceq99z
#
#                        artist_name                             album_uri  \
# 0                          the klf  spotify:album:4mc0zjntvp1ndd5lslxfjc
# 1                          pitbull  spotify:album:5xlacbvbsalrtpxnkkggxa
# 2                   britney spears  spotify:album:3wnxdumksmgmjrhegk80qx
# 3                        the kinks  spotify:album:6ll6hugnen4vlc8sj0zcse
# 4               the rolling stones  spotify:album:0c78nsgqx6vfnisnwixwod
# ...                            ...                                   ...
# 8870                 zombie nation  spotify:album:2qmrrouzqemrkfr9pbmdhd
# 8871                    topic, a7s  spotify:album:2nichqkijgw4r4dqfmg0a3
# 8872                     vandalism  spotify:album:2n506u3hkn3caedvajv5ct
# 8873  spiller, sophie ellis-bextor  spotify:album:20q3pgpyiyicf32x5l8pph
# 8874                        tiësto  spotify:album:0eyksxxtson8za95bucoxn
#
#                                              album_name  \
# 0                                      songs collection
# 1                        pitbull starring in rebelution
# 2        ...baby one more time (digital deluxe version)
# 3     lola vs. powerman and the moneygoround, pt. on...
# 4                                          let it bleed
# ...                                                 ...
# 8870                         kernkraft 400 single mixes
# 8871                       kernkraft 400 (a better day)
# 8872                                    never say never
# 8873  groovejet (if this ain't love) [feat. sophie e...
# 8874                                            lay low
#
#                                        album_artist_uri   album_artist_name  \
# 0                 spotify:artist:6dyrdrlnzskavxyg5irvch             the klf
# 1                 spotify:artist:0tnoyisbd1xyrbk9myaseg             pitbull
# 2                 spotify:artist:26dsoyclwsylmakd3tpor4      britney spears
# 3                 spotify:artist:1sqrv42e4pjeyfphs0tk9e           the kinks
# 4                 spotify:artist:22be4uq6banwshpvcdxlce  the rolling stones
# ...                                                 ...                 ...
# 8870              spotify:artist:7vfpnlbcxbbfs4kfbulksl       zombie nation
# 8871  spotify:artist:0u6gtibw46tfx7koq6unjz, spotify...          topic, a7s
# 8872              spotify:artist:1sczsjoyaihnnm9qlhzdnl           vandalism
# 8873              spotify:artist:4bmymfwdu9zlcitrumrewb             spiller
# 8874              spotify:artist:2o5jdhthvphrjdv3ceq99z              tiësto
#
#      album_release_date                                    album_image_url  \
# 0            1992-08-03  https://i.scdn.co/image/ab67616d0000b27355346b...
# 1            2009-10-23  https://i.scdn.co/image/ab67616d0000b27326d73a...
# 2            1999-01-12  https://i.scdn.co/image/ab67616d0000b2738e4986...
# 3            2014-10-20  https://i.scdn.co/image/ab67616d0000b2731e7c53...
# 4            1969-12-05  https://i.scdn.co/image/ab67616d0000b27373d927...
# ...                 ...                                                ...
# 8870         2006-03-07  https://i.scdn.co/image/ab67616d0000b273916e34...
# 8871         2022-06-17  https://i.scdn.co/image/ab67616d0000b273e1cafe...
# 8872         2005-10-24  https://i.scdn.co/image/ab67616d0000b273b65ad4...
# 8873         2000-08-14  https://i.scdn.co/image/ab67616d0000b27342781a...
# 8874         2023-01-06  https://i.scdn.co/image/ab67616d0000b273c8fdaf...
#
#       ...  speechiness  acousticness  instrumentalness liveness  valence  \
# 0     ...       0.0480      0.015800          0.112000   0.4080    0.504
# 1     ...       0.1490      0.014200          0.000021   0.2370    0.800
# 2     ...       0.0305      0.560000          0.000001   0.3380    0.706
# 3     ...       0.2590      0.568000          0.000051   0.0384    0.833
# 4     ...       0.0687      0.675000          0.000073   0.2890    0.497
# ...   ...          ...           ...               ...      ...      ...
# 8870  ...       0.0868      0.005500          0.901000   0.1460    0.487
# 8871  ...       0.0562      0.184000          0.000020   0.3090    0.400
# 8872  ...       0.0340      0.000354          0.011200   0.3380    0.767
# 8873  ...       0.0389      0.000132          0.088900   0.3610    0.626
# 8874  ...       0.1830      0.060700          0.000263   0.3460    0.420
#
#         tempo time_signature album_genres  \
# 0     111.458            4.0          NaN
# 1     127.045            4.0          NaN
# 2      74.981            4.0          NaN
# 3      75.311            4.0          NaN
# 4      85.818            4.0          NaN
# ...       ...            ...          ...
# 8870  140.064            4.0          NaN
# 8871  125.975            4.0          NaN
# 8872  130.978            4.0          NaN
# 8873  123.037            4.0          NaN
# 8874  122.060            4.0          NaN
#
#                                     label  \
# 0                     jams communications
# 1     mr.305/polo grounds music/j records
# 2                                    jive
# 3                       sanctuary records
# 4                   universal music group
# ...                                   ...
# 8870                          ukw records
# 8871                               virgin
# 8872                              vicious
# 8873                     defected records
# 8874                      musical freedom
#
#                                              copyrights
# 0     c 1992 copyright control, p 1992 jams communic...
# 1     p (p) 2009 rca/jive label group, a unit of son...
# 2                        p (p) 1999 zomba recording llc
# 3     c © 2014 sanctuary records group ltd., a bmg c...
# 4     c © 2002 abkco music & records inc., p ℗ 2002 ...
# ...                                                 ...
# 8870  c 2006 copyright control, p 2006 copyright con...
# 8871  c © 2022 topic, under exclusive license to uni...
# 8872  c 2005 vicious, a division of vicious recordin...
# 8873  c © 2021 defected records limited, p ℗ 2021 de...
# 8874  c © 2023 musical freedom label ltd., p ℗ 2023 ...
#
# [8875 rows x 35 columns]

# %%
tracks_10k_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8875 entries, 0 to 8874
# Data columns (total 35 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   track_uri            8875 non-null   object
#  1   track_name           8874 non-null   object
#  2   artist_uri           8873 non-null   object
#  3   artist_name          8874 non-null   object
#  4   album_uri            8873 non-null   object
#  5   album_name           8874 non-null   object
#  6   album_artist_uri     8873 non-null   object
#  7   album_artist_name    8873 non-null   object
#  8   album_release_date   8873 non-null   object
#  9   album_image_url      8871 non-null   object
#  10  disc_number          8875 non-null   int64
#  11  track_number         8875 non-null   int64
#  12  track_duration_(ms)  8875 non-null   int64
#  13  track_preview_url    6415 non-null   object
#  14  explicit             8875 non-null   bool
#  15  popularity           8875 non-null   int64
#  16  isrc                 8872 non-null   object
#  17  added_by             8875 non-null   object
#  18  added_at             8875 non-null   object
#  19  artist_genres        8340 non-null   object
#  20  danceability         8873 non-null   float64
#  21  energy               8873 non-null   float64
#  22  key                  8873 non-null   float64
#  23  loudness             8873 non-null   float64
#  24  mode                 8873 non-null   float64
#  25  speechiness          8873 non-null   float64
#  26  acousticness         8873 non-null   float64
#  27  instrumentalness     8873 non-null   float64
#  28  liveness             8873 non-null   float64
#  29  valence              8873 non-null   float64
#  30  tempo                8873 non-null   float64
#  31  time_signature       8873 non-null   float64
#  32  album_genres         0 non-null      float64
#  33  label                8870 non-null   object
#  34  copyrights           8853 non-null   object
# dtypes: bool(1), float64(13), int64(4), object(17)
# memory usage: 2.3+ MB

# %% [markdown]
# The 40k data set is mainly used to build the similarity matrix and the `recommend_songs` function.

# %%
tracks_40k_df = pd.read_csv("../data/spotify-40k-processed.csv")

# %%
tracks_40k_df
# Out:
#                                   track_uri  \
# 0      spotify:track:1xazlnvtthcdzt2ni1dtxo
# 1      spotify:track:6a8gbqilv8hbuw3c6uk9ph
# 2      spotify:track:70xtwbcvzcpaoddjftmcvi
# 3      spotify:track:1nxuwypjk5ko6dqj5t7bdu
# 4      spotify:track:72wztws6v7uu3amgmmekye
# ...                                     ...
# 40542  spotify:track:3uchi1gfoul5j5sweh0tch
# 40543  spotify:track:0p1oo2gremyucookzyayfu
# 40544  spotify:track:2om4burudnevk59ivixcwn
# 40545  spotify:track:4ri5ttugjm96tbqzd5ua7v
# 40546  spotify:track:5rvubrxvlptaebgjdsdzl5
#
#                                          track_name         artist_name  \
# 0           justified & ancient - stand by the jams             the klf
# 1                   i know you want me (calle ocho)             pitbull
# 2                from the bottom of my broken heart      britney spears
# 3                  apeman - 2014 remastered version           the kinks
# 4                you can't always get what you want  the rolling stones
# ...                                             ...                 ...
# 40542                                  i don't know               jon d
# 40543                                    the answer           big words
# 40544                                         25.22        allan rayman
# 40545                                  good feeling           jon jason
# 40546  cosmic angel - acoustic from capitol studios            grizfolk
#
#                                            artist_genres  danceability  \
# 0            acid house,ambient house,big beat,hip house         0.617
# 1                            dance pop,miami hip hop,pop         0.825
# 2                                          dance pop,pop         0.677
# 3      album rock,art rock,british invasion,classic r...         0.683
# 4          album rock,british invasion,classic rock,rock         0.319
# ...                                                  ...           ...
# 40542                                            unknown         0.669
# 40543                                     australian r&b         0.493
# 40544  canadian contemporary r&b,modern alternative rock         0.702
# 40545                                            unknown         0.509
# 40546  indie poptimism,indiecoustica,modern alternati...         0.639
#
#        energy  key  loudness  mode  speechiness  acousticness  \
# 0       0.872  8.0   -12.305   1.0       0.0480        0.0158
# 1       0.743  2.0    -5.995   1.0       0.1490        0.0142
# 2       0.665  7.0    -5.171   1.0       0.0305        0.5600
# 3       0.728  9.0    -8.920   1.0       0.2590        0.5680
# 4       0.627  0.0    -9.611   1.0       0.0687        0.6750
# ...       ...  ...       ...   ...          ...           ...
# 40542   0.228  2.0   -12.119   1.0       0.0690        0.7920
# 40543   0.727  1.0    -5.031   1.0       0.2170        0.0873
# 40544   0.524  7.0   -10.710   1.0       0.0793        0.3320
# 40545   0.286  8.0   -14.722   1.0       0.1230        0.4020
# 40546   0.461  6.0    -8.260   0.0       0.0493        0.3570
#
#        instrumentalness  liveness  valence    tempo
# 0              0.112000    0.4080    0.504  111.458
# 1              0.000021    0.2370    0.800  127.045
# 2              0.000001    0.3380    0.706   74.981
# 3              0.000051    0.0384    0.833   75.311
# 4              0.000073    0.2890    0.497   85.818
# ...                 ...       ...      ...      ...
# 40542          0.065000    0.0944    0.402   83.024
# 40543          0.000000    0.1290    0.289   73.259
# 40544          0.055300    0.2980    0.265  140.089
# 40545          0.000012    0.1310    0.259  121.633
# 40546          0.000057    0.1120    0.264  117.583
#
# [40547 rows x 15 columns]

# %%
tracks_40k_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40547 entries, 0 to 40546
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track_uri         40547 non-null  object
#  1   track_name        40546 non-null  object
#  2   artist_name       40546 non-null  object
#  3   artist_genres     40012 non-null  object
#  4   danceability      40545 non-null  float64
#  5   energy            40545 non-null  float64
#  6   key               40545 non-null  float64
#  7   loudness          40545 non-null  float64
#  8   mode              40545 non-null  float64
#  9   speechiness       40545 non-null  float64
#  10  acousticness      40545 non-null  float64
#  11  instrumentalness  40545 non-null  float64
#  12  liveness          40545 non-null  float64
#  13  valence           40545 non-null  float64
#  14  tempo             40545 non-null  float64
# dtypes: float64(11), object(4)
# memory usage: 4.6+ MB

# %% [markdown]
# The consolidated list of genres from the 10k data set is mainly used to support the `generate_random_tracks_balanced` function.

# %%
genres_10k_df = pd.read_csv("../data/genres-10k.csv")

# %%
genres_10k_df
# Out:
#                  genre  count
# 0           acid house      6
# 1        ambient house      7
# 2             big beat    105
# 3            hip house    123
# 4            dance pop   4362
# ...                ...    ...
# 2286   chinese hip hop      1
# 2287  chinese idol pop      1
# 2288   musica potosina      1
# 2289        weightless      1
# 2290  jazz guitar trio      1
#
# [2291 rows x 2 columns]

# %%
genres_10k_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2291 entries, 0 to 2290
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   genre   2291 non-null   object
#  1   count   2291 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 35.9+ KB

# %% [markdown]
# ### 3. Create a function for generating sub-genres

# %% [markdown]
# The following list of common genres was consolidated based on the EDA performed in the 2nd notebook.

# %%
# Common genres to choose from
common_genres = ['pop', 'rock', 'hip hop', 'rap', 'r&b', 'soul', 'dance', 'electronic', 'house', 'metal', 'punk', 'country']

# %% [markdown]
# The `common_genres` list was created initially to support the `top_subgenres` function. This function takes in different genres as a list of strings then outputs the top 5 sub-genres for each over-arching genre.
#
# The idea is to incorporate this function into the user studies so that users may choose specific sub-genres to generate random tracks. However, this idea was eventually retracted to reduce friction in the user journey. I also found that giving users the option to be as generic or as specific as they want when selecting genres is generally better for them.

# %%
def top_subgenres(genres_list):
    for genre in genres_list:
        if genre == 'rap':
            search_term = r'\brap\b'
            result = list(genres_10k_df[genres_10k_df['genre'].str.contains(search_term, case=False)].sort_values(by='count', ascending=False).head(6)['genre'])
        else:
            result = list(genres_10k_df[genres_10k_df['genre'].str.contains(genre, case=False)].sort_values(by='count', ascending=False).head(6)['genre'])
        
        if genre in result:
            result.remove(genre)
        else:
            result = result[:-1]

        print(f"'{genre}' sub-genres:")
        for i in result:
            print(i)
        print("\n")

# %% [markdown]
# Sample of how the `top_subgenres` function may be used.

# %%
top_subgenres(['pop','rock','dance'])
# Out:
# 'pop' sub-genres:
# dance pop
# pop rap
# pop rock
# post-teen pop
# electropop
#
#
# 'rock' sub-genres:
# modern rock
# pop rock
# classic rock
# soft rock
# indie rock
#
#
# 'dance' sub-genres:
# dance pop
# pop dance
# alternative dance
# australian dance
# dance rock

# %% [markdown]
# ### 4. Create `generate_random_tracks` function based on genres selected

# %% [markdown]
# Check all columns in `tracks_10k_df`.

# %%
tracks_10k_df.columns
# Out:
# Index(['track_uri', 'track_name', 'artist_uri', 'artist_name', 'album_uri',
#        'album_name', 'album_artist_uri', 'album_artist_name',
#        'album_release_date', 'album_image_url', 'disc_number', 'track_number',
#        'track_duration_(ms)', 'track_preview_url', 'explicit', 'popularity',
#        'isrc', 'added_by', 'added_at', 'artist_genres', 'danceability',
#        'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature',
#        'album_genres', 'label', 'copyrights'],
#       dtype='object')

# %% [markdown]
# Rows with null cells in the `'artist_genres'` column are removed.

# %%
tracks_10k_df['artist_genres'].isna().sum()
# Out:
# 535

# %%
tracks_10k_df.dropna(subset=['artist_genres'], inplace=True)

# %%
tracks_10k_df['artist_genres'].isna().sum()
# Out:
# 0

# %% [markdown]
# The cleaned up `tracks_10k_df` with no rows containing null `'artist_genres'` cells is exported as a new CSV file to develop the Streamlit app.

# %%
# tracks_10k_df.to_csv('../data/tracks-10k-processed.csv', index=False)

# %% [markdown]
# The `generate_random_tracks` function filters takes in a list of genres (`genres`) and an integer `n` to output a randomly generated list of `n` songs. The function searches through the `'artist_genres'` column of the 10k data set and outputs `n` random rows where the genres match the input genres.
#
# For the first 20 user studies, this function was used to generate random tracks for users. It seemed to work well for most users, where the list needed to be refreshed only 1-3 times before the user recognises at least 3 songs that they like.
#
# However, the function did not work well if the genres chosen by the user had a mix of overrepresented and underrepresented genres. For example, if a user chooses 'pop', 'rock' and 'alternative r&b', the popular genres ('pop' and 'rock') would be overly represented in the random list of tracks such that 'alternative r&b' tracks are rarely shown, if at all. This proved to be an issue because the user's personalised playlist would then end up being only representative of 1-2 of his favourite genres, instead of all 3.

# %% [markdown]
# The `generate_random_tracks` function works by generating `n` random songs for the user. Whether the user selects 1, 2 or 3 genres, `n` songs will still be displayed in the list. I found that the 'sweet spot' for the number of songs in each randomly generated list is 15.

# %%
def generate_random_tracks(genres, n):
    # Load data from 'tracks_10k_df'
    data = tracks_10k_df

    # Filter DataFrame based on specified genres
    filtered_data = data[data['artist_genres'].apply(lambda x: any(genre in x for genre in genres))]

    # Get the number of available tracks
    num_tracks_available = len(filtered_data)

    # Check if number of requested tracks (n) exceeds available tracks
    if n > num_tracks_available:
        raise ValueError(f"Requested number of tracks ({n}) exceeds available tracks ({num_tracks_available}).")

    # Randomly select n tracks
    random_indices = np.random.choice(num_tracks_available, n, replace=False)
    random_tracks = filtered_data.iloc[random_indices]

    # Extract track_name, artist_name pairs and artist_genres
    track_artist_genres = list(zip(random_tracks['track_name'], random_tracks['artist_name'], random_tracks['artist_genres']))
    random.shuffle(track_artist_genres)

    result = {i + 1: tpl for i, tpl in enumerate(track_artist_genres)}
    return result

# %% [markdown]
# To solve the issue of the underrepresentation of less popular genres in the random track generation, the `generate_random_tracks` was tweaked to create `generate_random_tracks_balanced` - this new function allows a more even sample of tracks to be displayed across all genres, regardless of its popularity or mainstream status.

# %% [markdown]
# The `generate_random_tracks_balanced` function works by taking 4 random tracks from each genre to generate the list. This "forces" the function to display an even sample of songs for each genre. However, a limitation to this is that a user will only be shown 5 songs if he chooses 1 genre, which is too little. To overcome this limitation, I enforced a rule where users needed to select at least 3 genres so as to generate a sufficiently long random list of (15) songs. The function also returns an error message "Choose at least 3 genres!"
#
# Note: Most users surveyed will select at most 5 genres.

# %%
# Convert df to dictionary
# To be used in the `generate_random_tracks` function
genres_10k_dict = dict(zip(genres_10k_df['genre'], genres_10k_df['count']))

# %%
def generate_random_tracks_balanced(genres):
    # Load data from 'tracks_10k_df'
    track_data = tracks_10k_df

    # Initialise empty data frame to store results
    songs = pd.DataFrame()

    # If less than 3 genres is input, an error message is shown
    if len(genres) < 3:
        return "Choose at least 3 genres!"
    else:
        # For each genre, load 4 random tracks
        for g in genres:
            # Error statement if user chooses a genre that does not exist
            if g not in genres_10k_dict.keys():
                print(f"The '{g}' genre does not exist.")
                return
            # Error statement if user chooses a genre with fewer than 20 tracks in the data set
            elif genres_10k_dict[g] < 20:
                print(f"Choose a genre other than '{g}' for better results.")
                return
            else:
                try:
                    # Append to 'songs' df using pd.concat()
                    songs_by_genre = track_data[track_data['artist_genres'].apply(lambda x: g in x)].sample(int(5))
                    songs = pd.concat([songs, songs_by_genre])
                except:
                    # Error statement in case a genre slips past the "elif" statement and has less than 5 songs
                    print(f"Choose a genre other than '{g}' for better results.")
                    return

    # Extract track_name, artist_name and artist_genres
    track_artist_genres = list(zip(songs['track_name'], songs['artist_name'], songs['artist_genres']))
    random.shuffle(track_artist_genres)

    result = {i + 1: tpl for i, tpl in enumerate(track_artist_genres)}
    return result

# %% [markdown]
# To further make the `generate_random_tracks_balanced` function more robust, error messages for the following edge cases are included:
# 1. A user chooses an obscure genre that does not exist in the data set
# 2. A user chooses an underrepresented genre with fewer than 20 songs in the data set

# %% [markdown]
# `generate_random_tracks_balanced` returns a dictionary of ('track_name', 'artist_name') tuples. To make the randomly generated list more readable for users during the user studies, the `track_viewer` function is created to convert the dictionary into a data frame.

# %%
def track_viewer(tracks_dict):
    if not tracks_dict:
        return

    try:
        # Create lists to store track details
        track_numbers = []
        track_names = []
        artist_names = []
        artist_genres = []
        
        # Extract information from the dictionary
        for key, value in tracks_dict.items():
            track_numbers.append(key)
            track_names.append(value[0])
            artist_names.append(value[1])
            artist_genres.append(value[2].replace(',', ', '))
        
        # Create a DataFrame with the extracted information
        df = pd.DataFrame({
            "track_number": track_numbers,
            "track_name": track_names,
            "artist_name": artist_names,
            "artist_genres": artist_genres,
        })

        # Set 'track_number' as the index
        df.set_index('track_number', inplace=True)
        
        # Display the DataFrame (table format)
        return df
    
    except:
        return "Choose at least 3 genres!"

# %% [markdown]
# Sample: `generate_random_tracks` returns a list of 12 'pop' songs when `genres = ['pop']`  and `n = 12`.

# %%
track_viewer(generate_random_tracks(['pop'], 12))
# Out:
#                                                  track_name  \
# track_number
# 1                                            you were right
# 2                                         pleasure and pain
# 3                                       here you come again
# 4                                                 thank you
# 5                                             make me (cry)
# 6                                               wild things
# 7                                          i love this life
# 8                            don't let me down (feat. daya)
# 9                                                     ghost
# 10                                                  the man
# 11            when you believe (from "the prince of egypt")
# 12                from this moment on - pop on-tour version
#
#                                 artist_name  \
# track_number
# 1                              rüfüs du sol
# 2                                  divinyls
# 3                              dolly parton
# 4                                      mkto
# 5                      noah cyrus, labrinth
# 6                                 san cisco
# 7                              kim cesarion
# 8                    the chainsmokers, daya
# 9                             justin bieber
# 10                             taylor swift
# 11            mariah carey, whitney houston
# 12                             shania twain
#
#                                                   artist_genres
# track_number
# 1                           australian electropop, indietronica
# 2                                 australian rock, new wave pop
# 3                    classic country pop, country, country dawn
# 4                                            pop, post-teen pop
# 5                              alt z, pop, indie poptimism, pop
# 6             australian indie, fremantle indie, metropopoli...
# 7                                     swedish pop, swedish soul
# 8                                          electropop, pop, pop
# 9                                             canadian pop, pop
# 10                                                          pop
# 11                dance pop, pop, urban contemporary, dance pop
# 12            canadian country, canadian pop, contemporary c...

# %% [markdown]
# Sample: `generate_random_tracks_balanced` returns a list of 20 'pop' songs when `genres = ['pop', 'rock', 'hip hop', 'edm']` (5 songs for each genre).

# %%
track_viewer(generate_random_tracks_balanced(['pop', 'rock', 'hip hop', 'edm']))
# Out:
#                                                      track_name  \
# track_number
# 1             get lucky (radio edit) [feat. pharrell william...
# 2                                you don't know me - radio edit
# 3                                 troublemaker (feat. flo rida)
# 4                                    can't take my eyes off you
# 5                                         satisfied (feat. max)
# 6                                          nothing from nothing
# 7                        beautiful people (feat. benny benassi)
# 8                                                  ready or not
# 9             dream a little dream of me - album version wit...
# 10                                        antmusic - remastered
# 11                                                sweat - remix
# 12                                             we're going home
# 13                                start me up - remastered 2009
# 14                                                        shine
# 15                                                 toosie slide
# 16                                                  it ain't me
# 17                                             for a better day
# 18                                                       on top
# 19                                            she wants to move
# 20                                                      on & on
#
#                                                     artist_name  \
# track_number
# 1                    daft punk, pharrell williams, nile rodgers
# 2                                               jax jones, raye
# 3                                           olly murs, flo rida
# 4                                                        lady a
# 5                                                 galantis, max
# 6                                                 billy preston
# 7                                    chris brown, benny benassi
# 8                    fugees, ms. lauryn hill, wyclef jean, pras
# 9                                         the mamas & the papas
# 10                                              adam & the ants
# 11            snoop dogg, david guetta, giorgio tuinfort, fr...
# 12                                                    vance joy
# 13                                           the rolling stones
# 14                                              vanessa amorosi
# 15                                                        drake
# 16                                           kygo, selena gomez
# 17                                                       avicii
# 18                                               flume, t-shirt
# 19                                                      n.e.r.d
# 20                                                         illy
#
#                                                   artist_genres
# track_number
# 1             electro, filter house, rock, dance pop, pop, d...
# 2             dance pop, edm, house, pop dance, uk dance, uk...
# 3             dance pop, pop, talent show, dance pop, miami ...
# 4             contemporary country, country, country dawn, c...
# 5             dance pop, edm, pop, pop dance, singer-songwri...
# 6                   funk, psychedelic soul, rock keyboard, soul
# 7                       r&b, rap, edm, electro house, pop dance
# 8             east coast hip hop, hip hop, neo soul, new jer...
# 9             classic rock, folk, folk rock, mellow gold, ps...
# 10                         new romantic, new wave, new wave pop
# 11            g funk, gangster rap, hip hop, pop rap, rap, w...
# 12                                        folk-pop, modern rock
# 13             album rock, british invasion, classic rock, rock
# 14            australian dance, australian pop, australian rock
# 15            canadian hip hop, canadian pop, hip hop, rap, ...
# 16            edm, pop, pop dance, tropical house, pop, post...
# 17                                          edm, pop, pop dance
# 18            australian dance, australian electropop, austr...
# 19                                    hip hop, virginia hip hop
# 20                          australian hip hop, australian trap

# %% [markdown]
# Sample: `generate_random_tracks_balanced` returns an error message when `genres = ['pop']`. User needs to select at least 3 genres.

# %%
track_viewer(generate_random_tracks_balanced(['pop']))
# Out:
# 'Choose at least 3 genres!'

# %% [markdown]
# Sample: `generate_random_tracks_balanced` returns an error message when a genre has less than 20 songs in the data set.

# %%
track_viewer(generate_random_tracks_balanced(['pop','r&b','classical']))
# Out:
# Choose a genre other than 'classical' for better results.

# %%
track_viewer(generate_random_tracks_balanced(['pop','french rock','vogue']))
# Out:
# Choose a genre other than 'french rock' for better results.

# %% [markdown]
# Sample: `generate_random_tracks_balanced` returns an error message when a genre that does not exist in the data set is input.

# %%
track_viewer(generate_random_tracks_balanced(['pop','r&b','nonsense']))
# Out:
# The 'nonsense' genre does not exist.

# %% [markdown]
# In the Streamlit app, I decided to tweak the if-else statements in the `generate_random_tracks_balanced` function to make it more visually impactful for the presentation (a consistent number of random tracks are shown regardless of the number of genres selected). The following block of code shows how the sampling is done when 1-2 genres are selected vs. 3 or more genres. This ensures that there is always 1 random tracks shown and all genres have an equal chance of being represented.
#
# ```
# # If 1 genre is chosen, 10 random songs are shown
#     if len(genres_list) == 1:
#         for g in genres_list:
#             # Append to 'songs' df using pd.concat()
#             songs_by_genre = track_data[track_data['artist_genres'].apply(lambda x: g in x)].sample(10)
#             songs = pd.concat([songs, songs_by_genre])
#     # If 2 genres are chosen, 5 random songs of each genre are selected and shown
#     elif len(genres_list) == 2:
#         for g in genres_list:
#             # Append to 'songs' df using pd.concat()
#             songs_by_genre = track_data[track_data['artist_genres'].apply(lambda x: g in x)].sample(5)
#             songs = pd.concat([songs, songs_by_genre])
#     # If 3 or more genres are chosen, 4 random songs of each genre are selected,
#     # but random sample of 10 songs are shown in the end
#     else:
#         for g in genres_list:
#             # Append to 'songs' df using pd.concat()
#             songs_by_genre = track_data[track_data['artist_genres'].apply(lambda x: g in x)].sample(4)
#             songs = pd.concat([songs, songs_by_genre])
#         songs = songs.sample(n=10, random_state=42)
# ```

# %% [markdown]
# ##### Sample output for `generate_random_tracks_balanced`

# %%
# Specify genres and number of random track pairs to generate
selected_genres = ['dance pop', 'singer-songwriter', 'electro house', 'folk']

# Generate random track pairs based on the specified genres
random_tracks_by_genre = generate_random_tracks_balanced(selected_genres)
random_tracks_by_genre
# Out:
# {1: ('2step (feat. budjerah)',
#   'ed sheeran, budjerah',
#   'pop,singer-songwriter pop,uk pop,australian indigenous,australian r&b'),
#  2: ("acceptable in the 80's",
#   'calvin harris',
#   'dance pop,edm,electro house,house,pop,progressive house,uk dance'),
#  3: ('back home again',
#   'john denver',
#   'classic country pop,folk,folk rock,mellow gold,singer-songwriter,soft rock'),
#  4: ('all for you', 'janet jackson', 'dance pop,r&b,urban contemporary'),
#  5: ('beautiful noise',
#   'neil diamond',
#   'adult standards,brill building pop,folk rock,heartland rock,mellow gold,singer-songwriter,soft rock,yacht rock'),
#  6: ('time of our lives - radio edit',
#   'pitbull, ne-yo',
#   'dance pop,miami hip hop,pop,dance pop,pop,r&b,urban contemporary'),
#  7: ("cathy's clown",
#   'the everly brothers',
#   'adult standards,folk rock,mellow gold,rock-and-roll,rockabilly,sunshine pop'),
#  8: ('my way',
#   'calvin harris',
#   'dance pop,edm,electro house,house,pop,progressive house,uk dance'),
#  9: ('dear mr. president',
#   'p!nk, indigo girls',
#   "dance pop,pop,ectofolk,folk,lilith,singer-songwriter,women's music"),
#  10: ('lana',
#   'roy orbison',
#   'adult standards,classic rock,folk rock,mellow gold,rock-and-roll,rockabilly,singer-songwriter'),
#  11: ('layla - acoustic; live at mtv unplugged, bray film studios, windsor, england, uk, 1/16/1992; 2013 remaster',
#   'eric clapton',
#   'album rock,blues rock,classic rock,electric blues,mellow gold,rock,singer-songwriter,soft rock'),
#  12: ('mockingbird',
#   'carly simon, james taylor',
#   'classic rock,folk,folk rock,heartland rock,mellow gold,singer-songwriter,soft rock,classic rock,folk,folk rock,heartland rock,mellow gold,singer-songwriter,soft rock'),
#  13: ("knockin' on heaven's door",
#   'bob dylan',
#   'classic rock,country rock,folk,folk rock,rock,roots rock,singer-songwriter'),
#  14: ('drinking from the bottle (feat. tinie tempah)',
#   'calvin harris, tinie tempah',
#   'dance pop,edm,electro house,house,pop,progressive house,uk dance,dance pop,grime,pop rap'),
#  15: ("let's get it started", 'black eyed peas', 'dance pop,pop,pop rap'),
#  16: ("(hey won't you play) another somebody done somebody wrong song - re-recorded in stereo",
#   'b.j. thomas',
#   'adult standards,bubblegum pop,classic country pop,folk rock,mellow gold,soft rock'),
#  17: ('daydreamer (feat. example) - radio edit',
#   'flux pavilion, example',
#   'brostep,classic dubstep,complextro,edm,electro house,hip house,uk dance'),
#  18: ('one thing right',
#   'marshmello, kane brown',
#   'brostep,edm,pop,progressive electro house,black americana,contemporary country,country,country road'),
#  19: ('it girl', 'jason derulo', 'dance pop,pop'),
#  20: ('carry out (featuring justin timberlake)',
#   'timbaland',
#   'dance pop,pop,pop rap')}

# %% [markdown]
# ##### Sample output for `track_viewer`

# %%
track_viewer(random_tracks_by_genre)
# Out:
#                                                      track_name  \
# track_number
# 1                                        2step (feat. budjerah)
# 2                                        acceptable in the 80's
# 3                                               back home again
# 4                                                   all for you
# 5                                               beautiful noise
# 6                                time of our lives - radio edit
# 7                                                 cathy's clown
# 8                                                        my way
# 9                                            dear mr. president
# 10                                                         lana
# 11            layla - acoustic; live at mtv unplugged, bray ...
# 12                                                  mockingbird
# 13                                    knockin' on heaven's door
# 14                drinking from the bottle (feat. tinie tempah)
# 15                                         let's get it started
# 16            (hey won't you play) another somebody done som...
# 17                      daydreamer (feat. example) - radio edit
# 18                                              one thing right
# 19                                                      it girl
# 20                      carry out (featuring justin timberlake)
#
#                               artist_name  \
# track_number
# 1                    ed sheeran, budjerah
# 2                           calvin harris
# 3                             john denver
# 4                           janet jackson
# 5                            neil diamond
# 6                          pitbull, ne-yo
# 7                     the everly brothers
# 8                           calvin harris
# 9                      p!nk, indigo girls
# 10                            roy orbison
# 11                           eric clapton
# 12              carly simon, james taylor
# 13                              bob dylan
# 14            calvin harris, tinie tempah
# 15                        black eyed peas
# 16                            b.j. thomas
# 17                 flux pavilion, example
# 18                 marshmello, kane brown
# 19                           jason derulo
# 20                              timbaland
#
#                                                   artist_genres
# track_number
# 1             pop, singer-songwriter pop, uk pop, australian...
# 2             dance pop, edm, electro house, house, pop, pro...
# 3             classic country pop, folk, folk rock, mellow g...
# 4                            dance pop, r&b, urban contemporary
# 5             adult standards, brill building pop, folk rock...
# 6             dance pop, miami hip hop, pop, dance pop, pop,...
# 7             adult standards, folk rock, mellow gold, rock-...
# 8             dance pop, edm, electro house, house, pop, pro...
# 9             dance pop, pop, ectofolk, folk, lilith, singer...
# 10            adult standards, classic rock, folk rock, mell...
# 11            album rock, blues rock, classic rock, electric...
# 12            classic rock, folk, folk rock, heartland rock,...
# 13            classic rock, country rock, folk, folk rock, r...
# 14            dance pop, edm, electro house, house, pop, pro...
# 15                                      dance pop, pop, pop rap
# 16            adult standards, bubblegum pop, classic countr...
# 17            brostep, classic dubstep, complextro, edm, ele...
# 18            brostep, edm, pop, progressive electro house, ...
# 19                                               dance pop, pop
# 20                                      dance pop, pop, pop rap

# %% [markdown]
# ### 5. Generate cosine similarity matrix for all songs in the `tracks` data set

# %% [markdown]
# The 40k track data set will be used to build the similarity matrix.

# %% [markdown]
# ##### Data pre-processing before one-hot encoding `artist_genres` column

# %%
tracks_40k_df.columns
# Out:
# Index(['track_uri', 'track_name', 'artist_name', 'artist_genres',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo'],
#       dtype='object')

# %% [markdown]
# The cells in `'artist_genres'` column are currently strings `'acid house,ambient house,big beat,hip house'`. I'd like to convert each string into a list of strings `['acid house','ambient house','big beat','hip house']` with each representing a genre.

# %%
tracks_40k_df['artist_genres']
# Out:
# 0              acid house,ambient house,big beat,hip house
# 1                              dance pop,miami hip hop,pop
# 2                                            dance pop,pop
# 3        album rock,art rock,british invasion,classic r...
# 4            album rock,british invasion,classic rock,rock
#                                ...
# 40542                                              unknown
# 40543                                       australian r&b
# 40544    canadian contemporary r&b,modern alternative rock
# 40545                                              unknown
# 40546    indie poptimism,indiecoustica,modern alternati...
# Name: artist_genres, Length: 40547, dtype: object

# %% [markdown]
# The `extract_genres` function splits the genre string based on the comma, then stores each genre into a list as a string.

# %%
def extract_genres(input_string):
    # Check for null or missing values
    if pd.isna(input_string):
        return []
    # Split the input string based on the comma delimiter
    else:
        genre_list = input_string.split(',')
        return genre_list

# %% [markdown]
# Test case to see if the `extract_genres` function works as intended. A new column called `'genres_list'` is created to store the reformatted genres.

# %%
# Create a new column called "genres_list" which takes the string from "artist_genres" and converts it into a list
tracks_40k_df['genres_list'] = tracks_40k_df['artist_genres'].apply(lambda x: extract_genres(x) if isinstance(x, str) else False)
tracks_40k_df['genres_list']
# Out:
# 0         [acid house, ambient house, big beat, hip house]
# 1                          [dance pop, miami hip hop, pop]
# 2                                         [dance pop, pop]
# 3        [album rock, art rock, british invasion, class...
# 4        [album rock, british invasion, classic rock, r...
#                                ...
# 40542                                            [unknown]
# 40543                                     [australian r&b]
# 40544    [canadian contemporary r&b, modern alternative...
# 40545                                            [unknown]
# 40546    [indie poptimism, indiecoustica, modern altern...
# Name: genres_list, Length: 40547, dtype: object

# %% [markdown]
# The `tracks_40k_df` is duplicated to generate the cosine similarity matrix. This is to prevent the original `tracks_40k_df` from being modified as we might still need to use it.

# %%
# Drop 'artist_genres' and 'track_uri' column
similarity_data = tracks_40k_df.drop(['artist_genres', 'track_uri'], axis=1)
similarity_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40547 entries, 0 to 40546
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track_name        40546 non-null  object
#  1   artist_name       40546 non-null  object
#  2   danceability      40545 non-null  float64
#  3   energy            40545 non-null  float64
#  4   key               40545 non-null  float64
#  5   loudness          40545 non-null  float64
#  6   mode              40545 non-null  float64
#  7   speechiness       40545 non-null  float64
#  8   acousticness      40545 non-null  float64
#  9   instrumentalness  40545 non-null  float64
#  10  liveness          40545 non-null  float64
#  11  valence           40545 non-null  float64
#  12  tempo             40545 non-null  float64
#  13  genres_list       40547 non-null  object
# dtypes: float64(11), object(3)
# memory usage: 4.3+ MB

# %% [markdown]
# Double check if there are any null cells in the `genres_list` column.

# %%
similarity_data['genres_list'].isna().sum()
# Out:
# 0

# %% [markdown]
# Set `'track_name'` and `'artist_name'` as indices.

# %%
similarity_data.set_index(['track_name', 'artist_name'], inplace=True)

# %% [markdown]
# ##### One-hot encode `artist_genres` column

# %% [markdown]
# Apart from the indices `track_name` and `artist_name`, the only other non-numeric feature is `genres_list`.
#
# We will one hot encode the `genres_list` column. One-hot encoding non-numeric features helps the cosine similarity matrix by converting categorical data into numerical representations, ensuring equal importance of categories, enabling the cosine similarity matrix to capture similarities based on both numerical and categorical attributes accurately.

# %%
import pandas as pd

def one_hot_encode_genres(df, column_name='genres_list'):
    """
    One-hot encodes the genres in the specified column of the DataFrame.

    Args:
        df (pandas.DataFrame): The input DataFrame.
        column_name (str, optional): The name of the column to be encoded. Default is 'genres_list'.

    Returns:
        pandas.DataFrame: The original DataFrame with additional columns for each genre.
    """
    # Create a duplicate copy of the input df
    df = df.copy()

    # Explode the genres column into separate rows
    exploded = df[column_name].explode()

    # Get a list of all unique genres
    all_genres = exploded.unique()

    # Use list comprehension to filter out null genres
    filtered_genres = [genre for genre in all_genres if genre and not pd.isna(genre)]

    # Create a list to hold the one-hot encoded genre DataFrames
    genre_dfs = []

    # Create one-hot encoded DataFrames for each genre
    for genre in filtered_genres:
        new_column_name = f'genre_{genre.replace(" ", "_")}'
        new_column = df[column_name].apply(lambda genres: int(genre in genres) if isinstance(genres, list) else 0)
        genre_dfs.append(new_column.rename(new_column_name))

    # Concatenate all the one-hot encoded genre DataFrames along the columns axis
    if genre_dfs:
        df = pd.concat([df] + genre_dfs, axis=1)

    # Drop the original genres column
    df = df.drop(column_name, axis=1)

    return df

# %%
encoded_similarity_data = one_hot_encode_genres(similarity_data)
encoded_similarity_data
# Out:
#                                                                  danceability  \
# track_name                                   artist_name
# justified & ancient - stand by the jams      the klf                    0.617
# i know you want me (calle ocho)              pitbull                    0.825
# from the bottom of my broken heart           britney spears             0.677
# apeman - 2014 remastered version             the kinks                  0.683
# you can't always get what you want           the rolling stones         0.319
# ...                                                                       ...
# i don't know                                 jon d                      0.669
# the answer                                   big words                  0.493
# 25.22                                        allan rayman               0.702
# good feeling                                 jon jason                  0.509
# cosmic angel - acoustic from capitol studios grizfolk                   0.639
#
#                                                                  energy  key  \
# track_name                                   artist_name
# justified & ancient - stand by the jams      the klf              0.872  8.0
# i know you want me (calle ocho)              pitbull              0.743  2.0
# from the bottom of my broken heart           britney spears       0.665  7.0
# apeman - 2014 remastered version             the kinks            0.728  9.0
# you can't always get what you want           the rolling stones   0.627  0.0
# ...                                                                 ...  ...
# i don't know                                 jon d                0.228  2.0
# the answer                                   big words            0.727  1.0
# 25.22                                        allan rayman         0.524  7.0
# good feeling                                 jon jason            0.286  8.0
# cosmic angel - acoustic from capitol studios grizfolk             0.461  6.0
#
#                                                                  loudness  \
# track_name                                   artist_name
# justified & ancient - stand by the jams      the klf              -12.305
# i know you want me (calle ocho)              pitbull               -5.995
# from the bottom of my broken heart           britney spears        -5.171
# apeman - 2014 remastered version             the kinks             -8.920
# you can't always get what you want           the rolling stones    -9.611
# ...                                                                   ...
# i don't know                                 jon d                -12.119
# the answer                                   big words             -5.031
# 25.22                                        allan rayman         -10.710
# good feeling                                 jon jason            -14.722
# cosmic angel - acoustic from capitol studios grizfolk              -8.260
#
#                                                                  mode  \
# track_name                                   artist_name
# justified & ancient - stand by the jams      the klf              1.0
# i know you want me (calle ocho)              pitbull              1.0
# from the bottom of my broken heart           britney spears       1.0
# apeman - 2014 remastered version             the kinks            1.0
# you can't always get what you want           the rolling stones   1.0
# ...                                                               ...
# i don't know                                 jon d                1.0
# the answer                                   big words            1.0
# 25.22                                        allan rayman         1.0
# good feeling                                 jon jason            1.0
# cosmic angel - acoustic from capitol studios grizfolk             0.0
#
#                                                                  speechiness  \
# track_name                                   artist_name
# justified & ancient - stand by the jams      the klf                  0.0480
# i know you want me (calle ocho)              pitbull                  0.1490
# from the bottom of my broken heart           britney spears           0.0305
# apeman - 2014 remastered version             the kinks                0.2590
# you can't always get what you want           the rolling stones       0.0687
# ...                                                                      ...
# i don't know                                 jon d                    0.0690
# the answer                                   big words                0.2170
# 25.22                                        allan rayman             0.0793
# good feeling                                 jon jason                0.1230
# cosmic angel - acoustic from capitol studios grizfolk                 0.0493
#
#                                                                  acousticness  \
# track_name                                   artist_name
# justified & ancient - stand by the jams      the klf                   0.0158
# i know you want me (calle ocho)              pitbull                   0.0142
# from the bottom of my broken heart           britney spears            0.5600
# apeman - 2014 remastered version             the kinks                 0.5680
# you can't always get what you want           the rolling stones        0.6750
# ...                                                                       ...
# i don't know                                 jon d                     0.7920
# the answer                                   big words                 0.0873
# 25.22                                        allan rayman              0.3320
# good feeling                                 jon jason                 0.4020
# cosmic angel - acoustic from capitol studios grizfolk                  0.3570
#
#                                                                  instrumentalness  \
# track_name                                   artist_name
# justified & ancient - stand by the jams      the klf                     0.112000
# i know you want me (calle ocho)              pitbull                     0.000021
# from the bottom of my broken heart           britney spears              0.000001
# apeman - 2014 remastered version             the kinks                   0.000051
# you can't always get what you want           the rolling stones          0.000073
# ...                                                                           ...
# i don't know                                 jon d                       0.065000
# the answer                                   big words                   0.000000
# 25.22                                        allan rayman                0.055300
# good feeling                                 jon jason                   0.000012
# cosmic angel - acoustic from capitol studios grizfolk                    0.000057
#
#                                                                  liveness  \
# track_name                                   artist_name
# justified & ancient - stand by the jams      the klf               0.4080
# i know you want me (calle ocho)              pitbull               0.2370
# from the bottom of my broken heart           britney spears        0.3380
# apeman - 2014 remastered version             the kinks             0.0384
# you can't always get what you want           the rolling stones    0.2890
# ...                                                                   ...
# i don't know                                 jon d                 0.0944
# the answer                                   big words             0.1290
# 25.22                                        allan rayman          0.2980
# good feeling                                 jon jason             0.1310
# cosmic angel - acoustic from capitol studios grizfolk              0.1120
#
#                                                                  valence  ...  \
# track_name                                   artist_name                  ...
# justified & ancient - stand by the jams      the klf               0.504  ...
# i know you want me (calle ocho)              pitbull               0.800  ...
# from the bottom of my broken heart           britney spears        0.706  ...
# apeman - 2014 remastered version             the kinks             0.833  ...
# you can't always get what you want           the rolling stones    0.497  ...
# ...                                                                  ...  ...
# i don't know                                 jon d                 0.402  ...
# the answer                                   big words             0.289  ...
# 25.22                                        allan rayman          0.265  ...
# good feeling                                 jon jason             0.259  ...
# cosmic angel - acoustic from capitol studios grizfolk              0.264  ...
#
#                                                                  genre_danish_metal  \
# track_name                                   artist_name
# justified & ancient - stand by the jams      the klf                              0
# i know you want me (calle ocho)              pitbull                              0
# from the bottom of my broken heart           britney spears                       0
# apeman - 2014 remastered version             the kinks                            0
# you can't always get what you want           the rolling stones                   0
# ...                                                                             ...
# i don't know                                 jon d                                0
# the answer                                   big words                            0
# 25.22                                        allan rayman                         0
# good feeling                                 jon jason                            0
# cosmic angel - acoustic from capitol studios grizfolk                             0
#
#                                                                  genre_little_rock_indie  \
# track_name                                   artist_name
# justified & ancient - stand by the jams      the klf                                   0
# i know you want me (calle ocho)              pitbull                                   0
# from the bottom of my broken heart           britney spears                            0
# apeman - 2014 remastered version             the kinks                                 0
# you can't always get what you want           the rolling stones                        0
# ...                                                                                  ...
# i don't know                                 jon d                                     0
# the answer                                   big words                                 0
# 25.22                                        allan rayman                              0
# good feeling                                 jon jason                                 0
# cosmic angel - acoustic from capitol studios grizfolk                                  0
#
#                                                                  genre_african_percussion  \
# track_name                                   artist_name
# justified & ancient - stand by the jams      the klf                                    0
# i know you want me (calle ocho)              pitbull                                    0
# from the bottom of my broken heart           britney spears                             0
# apeman - 2014 remastered version             the kinks                                  0
# you can't always get what you want           the rolling stones                         0
# ...                                                                                   ...
# i don't know                                 jon d                                      0
# the answer                                   big words                                  0
# 25.22                                        allan rayman                               0
# good feeling                                 jon jason                                  0
# cosmic angel - acoustic from capitol studios grizfolk                                   0
#
#                                                                  genre_igbo_pop  \
# track_name                                   artist_name
# justified & ancient - stand by the jams      the klf                          0
# i know you want me (calle ocho)              pitbull                          0
# from the bottom of my broken heart           britney spears                   0
# apeman - 2014 remastered version             the kinks                        0
# you can't always get what you want           the rolling stones               0
# ...                                                                         ...
# i don't know                                 jon d                            0
# the answer                                   big words                        0
# 25.22                                        allan rayman                     0
# good feeling                                 jon jason                        0
# cosmic angel - acoustic from capitol studios grizfolk                         0
#
#                                                                  genre_steel_guitar  \
# track_name                                   artist_name
# justified & ancient - stand by the jams      the klf                              0
# i know you want me (calle ocho)              pitbull                              0
# from the bottom of my broken heart           britney spears                       0
# apeman - 2014 remastered version             the kinks                            0
# you can't always get what you want           the rolling stones                   0
# ...                                                                             ...
# i don't know                                 jon d                                0
# the answer                                   big words                            0
# 25.22                                        allan rayman                         0
# good feeling                                 jon jason                            0
# cosmic angel - acoustic from capitol studios grizfolk                             0
#
#                                                                  genre_chinese_hip_hop  \
# track_name                                   artist_name
# justified & ancient - stand by the jams      the klf                                 0
# i know you want me (calle ocho)              pitbull                                 0
# from the bottom of my broken heart           britney spears                          0
# apeman - 2014 remastered version             the kinks                               0
# you can't always get what you want           the rolling stones                      0
# ...                                                                                ...
# i don't know                                 jon d                                   0
# the answer                                   big words                               0
# 25.22                                        allan rayman                            0
# good feeling                                 jon jason                               0
# cosmic angel - acoustic from capitol studios grizfolk                                0
#
#                                                                  genre_chinese_idol_pop  \
# track_name                                   artist_name
# justified & ancient - stand by the jams      the klf                                  0
# i know you want me (calle ocho)              pitbull                                  0
# from the bottom of my broken heart           britney spears                           0
# apeman - 2014 remastered version             the kinks                                0
# you can't always get what you want           the rolling stones                       0
# ...                                                                                 ...
# i don't know                                 jon d                                    0
# the answer                                   big words                                0
# 25.22                                        allan rayman                             0
# good feeling                                 jon jason                                0
# cosmic angel - acoustic from capitol studios grizfolk                                 0
#
#                                                                  genre_musica_potosina  \
# track_name                                   artist_name
# justified & ancient - stand by the jams      the klf                                 0
# i know you want me (calle ocho)              pitbull                                 0
# from the bottom of my broken heart           britney spears                          0
# apeman - 2014 remastered version             the kinks                               0
# you can't always get what you want           the rolling stones                      0
# ...                                                                                ...
# i don't know                                 jon d                                   0
# the answer                                   big words                               0
# 25.22                                        allan rayman                            0
# good feeling                                 jon jason                               0
# cosmic angel - acoustic from capitol studios grizfolk                                0
#
#                                                                  genre_weightless  \
# track_name                                   artist_name
# justified & ancient - stand by the jams      the klf                            0
# i know you want me (calle ocho)              pitbull                            0
# from the bottom of my broken heart           britney spears                     0
# apeman - 2014 remastered version             the kinks                          0
# you can't always get what you want           the rolling stones                 0
# ...                                                                           ...
# i don't know                                 jon d                              0
# the answer                                   big words                          0
# 25.22                                        allan rayman                       0
# good feeling                                 jon jason                          0
# cosmic angel - acoustic from capitol studios grizfolk                           0
#
#                                                                  genre_jazz_guitar_trio
# track_name                                   artist_name
# justified & ancient - stand by the jams      the klf                                  0
# i know you want me (calle ocho)              pitbull                                  0
# from the bottom of my broken heart           britney spears                           0
# apeman - 2014 remastered version             the kinks                                0
# you can't always get what you want           the rolling stones                       0
# ...                                                                                 ...
# i don't know                                 jon d                                    0
# the answer                                   big words                                0
# 25.22                                        allan rayman                             0
# good feeling                                 jon jason                                0
# cosmic angel - acoustic from capitol studios grizfolk                                 0
#
# [40547 rows x 2302 columns]

# %% [markdown]
# There are 2291 genres + 11 remaining non-index features.
# Hence, total number of columns after one hot encoding = 2302.

# %% [markdown]
# The following three cells serve to check if the one hot encoding function worked as intended on three sample genres: pop rock, metal and country.

# %%
encoded_similarity_data['genre_pop_rock'].value_counts()
# Out:
# genre_pop_rock
# 0    38433
# 1     2114
# Name: count, dtype: int64

# %%
encoded_similarity_data['genre_metal'].value_counts()
# Out:
# genre_metal
# 0    40353
# 1      194
# Name: count, dtype: int64

# %%
encoded_similarity_data['genre_country'].value_counts()
# Out:
# genre_country
# 0    38785
# 1     1762
# Name: count, dtype: int64

# %%
encoded_similarity_data.shape
# Out:
# (40547, 2302)

# %% [markdown]
# ##### Normalise values

# %% [markdown]
# Before performing cosine similarity, we need to normalise values in the data frame.
#
# Normalisation ensures that all features contribute equally to the similarity calculation, as cosine similarity is sensitive to the scale of the feature values. Without normalisation, features with larger scales might dominate the similarity calculation, leading to inaccurate results.

# %%
# Create a StandardScaler object
scaler = StandardScaler()

# Define the numerical columns to scale
numerical_columns = ['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness',
                     'instrumentalness', 'liveness', 'valence', 'tempo']

# Apply standardization to the numerical columns
encoded_similarity_data[numerical_columns] = scaler.fit_transform(encoded_similarity_data[numerical_columns])

# %% [markdown]
# ##### Fill null values

# %% [markdown]
# Before performing cosine similarity, we also need to fill all null values.
#
# Null values can distort the similarity calculation, as they introduce sparsity and uncertainty into the data. Filling null values with appropriate values (e.g., mean, median, or a constant) ensures that all instances have complete information, allowing for a more accurate similarity computation.

# %% [markdown]
# Since the number of cells with null values appear very insignificant, I decided to fill the null values with `0`.

# %%
encoded_similarity_data.isna().sum()
# Out:
# danceability              2
# energy                    2
# key                       2
# loudness                  2
# mode                      2
#                          ..
# genre_chinese_hip_hop     0
# genre_chinese_idol_pop    0
# genre_musica_potosina     0
# genre_weightless          0
# genre_jazz_guitar_trio    0
# Length: 2302, dtype: int64

# %%
encoded_similarity_data = encoded_similarity_data.fillna(0)

# %%
encoded_similarity_data.isna().sum()
# Out:
# danceability              0
# energy                    0
# key                       0
# loudness                  0
# mode                      0
#                          ..
# genre_chinese_hip_hop     0
# genre_chinese_idol_pop    0
# genre_musica_potosina     0
# genre_weightless          0
# genre_jazz_guitar_trio    0
# Length: 2302, dtype: int64

# %% [markdown]
# ##### Generate similarity matrix using `cosine_similarity`

# %% [markdown]
# `cosine_similarity` computes the pairwise cosine similarity between all rows (instances) in the `encoded_similarity_data`. This square matrix is stored in a new data frame `track_sim`, where both rows and columns represent all the songs in the data set.

# %%
track_sim = pd.DataFrame(cosine_similarity(encoded_similarity_data), columns=encoded_similarity_data.index, index=encoded_similarity_data.index)
print(track_sim.shape)
track_sim.head(20)
# Out:
# (40547, 40547)
# track_name                                                                      justified & ancient - stand by the jams  \
# artist_name                                                                                                     the klf
# track_name                                         artist_name
# justified & ancient - stand by the jams            the klf                                                     1.000000
# i know you want me (calle ocho)                    pitbull                                                     0.063919
# from the bottom of my broken heart                 britney spears                                              0.138761
# apeman - 2014 remastered version                   the kinks                                                  -0.004569
# you can't always get what you want                 the rolling stones                                         -0.031267
# don't stop - 2004 remaster                         fleetwood mac                                               0.127262
# eastside (with halsey & khalid)                    benny blanco, halsey, khalid                               -0.214441
# something about the way you look tonight - edit... elton john                                                 -0.036018
# juke box hero                                      foreigner                                                  -0.043722
# mercy                                              shawn mendes                                               -0.107261
# it's like that                                     run–d.m.c., jason nevins                                    0.311119
# here without you                                   3 doors down                                               -0.017767
# listen to the band - single version                the monkees                                                 0.119576
# with a little luck - remastered 1993               wings                                                       0.030728
# sing                                               ed sheeran                                                 -0.180715
# mississippi                                        pussycat                                                    0.464071
# flava                                              nathaniel                                                  -0.167178
# baby sittin' boogie - radio version                buzz clifford                                              -0.170621
# dr. love                                           tina charles                                                0.215933
# landslide (glee cast version) (feat. gwyneth pa... glee cast, gwyneth paltrow                                 -0.281180
#
# track_name                                                                      i know you want me (calle ocho)  \
# artist_name                                                                                             pitbull
# track_name                                         artist_name
# justified & ancient - stand by the jams            the klf                                             0.063919
# i know you want me (calle ocho)                    pitbull                                             1.000000
# from the bottom of my broken heart                 britney spears                                      0.318152
# apeman - 2014 remastered version                   the kinks                                           0.132411
# you can't always get what you want                 the rolling stones                                 -0.190212
# don't stop - 2004 remaster                         fleetwood mac                                       0.215280
# eastside (with halsey & khalid)                    benny blanco, halsey, khalid                       -0.061195
# something about the way you look tonight - edit... elton john                                         -0.078176
# juke box hero                                      foreigner                                          -0.124597
# mercy                                              shawn mendes                                       -0.151043
# it's like that                                     run–d.m.c., jason nevins                            0.244341
# here without you                                   3 doors down                                       -0.341376
# listen to the band - single version                the monkees                                        -0.025428
# with a little luck - remastered 1993               wings                                              -0.223790
# sing                                               ed sheeran                                          0.313052
# mississippi                                        pussycat                                            0.004982
# flava                                              nathaniel                                           0.390635
# baby sittin' boogie - radio version                buzz clifford                                      -0.027043
# dr. love                                           tina charles                                        0.402969
# landslide (glee cast version) (feat. gwyneth pa... glee cast, gwyneth paltrow                          0.127940
#
# track_name                                                                      from the bottom of my broken heart  \
# artist_name                                                                                         britney spears
# track_name                                         artist_name
# justified & ancient - stand by the jams            the klf                                                0.138761
# i know you want me (calle ocho)                    pitbull                                                0.318152
# from the bottom of my broken heart                 britney spears                                         1.000000
# apeman - 2014 remastered version                   the kinks                                              0.299550
# you can't always get what you want                 the rolling stones                                     0.241086
# don't stop - 2004 remaster                         fleetwood mac                                          0.146539
# eastside (with halsey & khalid)                    benny blanco, halsey, khalid                           0.043655
# something about the way you look tonight - edit... elton john                                            -0.169054
# juke box hero                                      foreigner                                             -0.279310
# mercy                                              shawn mendes                                          -0.174026
# it's like that                                     run–d.m.c., jason nevins                              -0.017728
# here without you                                   3 doors down                                          -0.273082
# listen to the band - single version                the monkees                                           -0.218978
# with a little luck - remastered 1993               wings                                                 -0.229486
# sing                                               ed sheeran                                             0.288568
# mississippi                                        pussycat                                               0.317758
# flava                                              nathaniel                                              0.179757
# baby sittin' boogie - radio version                buzz clifford                                          0.177766
# dr. love                                           tina charles                                           0.155249
# landslide (glee cast version) (feat. gwyneth pa... glee cast, gwyneth paltrow                            -0.023282
#
# track_name                                                                      apeman - 2014 remastered version  \
# artist_name                                                                                            the kinks
# track_name                                         artist_name
# justified & ancient - stand by the jams            the klf                                             -0.004569
# i know you want me (calle ocho)                    pitbull                                              0.132411
# from the bottom of my broken heart                 britney spears                                       0.299550
# apeman - 2014 remastered version                   the kinks                                            1.000000
# you can't always get what you want                 the rolling stones                                   0.278516
# don't stop - 2004 remaster                         fleetwood mac                                        0.412918
# eastside (with halsey & khalid)                    benny blanco, halsey, khalid                         0.316828
# something about the way you look tonight - edit... elton john                                           0.057642
# juke box hero                                      foreigner                                            0.020297
# mercy                                              shawn mendes                                        -0.116126
# it's like that                                     run–d.m.c., jason nevins                             0.066577
# here without you                                   3 doors down                                        -0.225490
# listen to the band - single version                the monkees                                         -0.101138
# with a little luck - remastered 1993               wings                                                0.149925
# sing                                               ed sheeran                                           0.195902
# mississippi                                        pussycat                                             0.168394
# flava                                              nathaniel                                            0.106380
# baby sittin' boogie - radio version                buzz clifford                                        0.350890
# dr. love                                           tina charles                                         0.153630
# landslide (glee cast version) (feat. gwyneth pa... glee cast, gwyneth paltrow                          -0.136324
#
# track_name                                                                      you can't always get what you want  \
# artist_name                                                                                     the rolling stones
# track_name                                         artist_name
# justified & ancient - stand by the jams            the klf                                               -0.031267
# i know you want me (calle ocho)                    pitbull                                               -0.190212
# from the bottom of my broken heart                 britney spears                                         0.241086
# apeman - 2014 remastered version                   the kinks                                              0.278516
# you can't always get what you want                 the rolling stones                                     1.000000
# don't stop - 2004 remaster                         fleetwood mac                                         -0.015129
# eastside (with halsey & khalid)                    benny blanco, halsey, khalid                           0.079169
# something about the way you look tonight - edit... elton john                                             0.079884
# juke box hero                                      foreigner                                              0.040025
# mercy                                              shawn mendes                                          -0.467329
# it's like that                                     run–d.m.c., jason nevins                              -0.320428
# here without you                                   3 doors down                                          -0.275559
# listen to the band - single version                the monkees                                            0.272313
# with a little luck - remastered 1993               wings                                                  0.096969
# sing                                               ed sheeran                                            -0.378574
# mississippi                                        pussycat                                              -0.150238
# flava                                              nathaniel                                             -0.289252
# baby sittin' boogie - radio version                buzz clifford                                          0.307402
# dr. love                                           tina charles                                           0.071367
# landslide (glee cast version) (feat. gwyneth pa... glee cast, gwyneth paltrow                             0.129383
#
# track_name                                                                      don't stop - 2004 remaster  \
# artist_name                                                                                  fleetwood mac
# track_name                                         artist_name
# justified & ancient - stand by the jams            the klf                                        0.127262
# i know you want me (calle ocho)                    pitbull                                        0.215280
# from the bottom of my broken heart                 britney spears                                 0.146539
# apeman - 2014 remastered version                   the kinks                                      0.412918
# you can't always get what you want                 the rolling stones                            -0.015129
# don't stop - 2004 remaster                         fleetwood mac                                  1.000000
# eastside (with halsey & khalid)                    benny blanco, halsey, khalid                  -0.240193
# something about the way you look tonight - edit... elton john                                     0.337696
# juke box hero                                      foreigner                                      0.459914
# mercy                                              shawn mendes                                   0.071861
# it's like that                                     run–d.m.c., jason nevins                       0.279844
# here without you                                   3 doors down                                   0.049164
# listen to the band - single version                the monkees                                    0.021450
# with a little luck - remastered 1993               wings                                          0.243339
# sing                                               ed sheeran                                     0.344031
# mississippi                                        pussycat                                       0.422228
# flava                                              nathaniel                                      0.260598
# baby sittin' boogie - radio version                buzz clifford                                  0.093103
# dr. love                                           tina charles                                   0.331543
# landslide (glee cast version) (feat. gwyneth pa... glee cast, gwyneth paltrow                     0.012752
#
# track_name                                                                      eastside (with halsey & khalid)  \
# artist_name                                                                        benny blanco, halsey, khalid
# track_name                                         artist_name
# justified & ancient - stand by the jams            the klf                                            -0.214441
# i know you want me (calle ocho)                    pitbull                                            -0.061195
# from the bottom of my broken heart                 britney spears                                      0.043655
# apeman - 2014 remastered version                   the kinks                                           0.316828
# you can't always get what you want                 the rolling stones                                  0.079169
# don't stop - 2004 remaster                         fleetwood mac                                      -0.240193
# eastside (with halsey & khalid)                    benny blanco, halsey, khalid                        1.000000
# something about the way you look tonight - edit... elton john                                         -0.302533
# juke box hero                                      foreigner                                          -0.208548
# mercy                                              shawn mendes                                        0.214721
# it's like that                                     run–d.m.c., jason nevins                           -0.254700
# here without you                                   3 doors down                                        0.003652
# listen to the band - single version                the monkees                                        -0.255714
# with a little luck - remastered 1993               wings                                               0.072963
# sing                                               ed sheeran                                          0.097642
# mississippi                                        pussycat                                           -0.297855
# flava                                              nathaniel                                          -0.004789
# baby sittin' boogie - radio version                buzz clifford                                       0.067594
# dr. love                                           tina charles                                       -0.290283
# landslide (glee cast version) (feat. gwyneth pa... glee cast, gwyneth paltrow                         -0.322830
#
# track_name                                                                      something about the way you look tonight - edit version  \
# artist_name                                                                                                                  elton john
# track_name                                         artist_name
# justified & ancient - stand by the jams            the klf                                                               -0.036018
# i know you want me (calle ocho)                    pitbull                                                               -0.078176
# from the bottom of my broken heart                 britney spears                                                        -0.169054
# apeman - 2014 remastered version                   the kinks                                                              0.057642
# you can't always get what you want                 the rolling stones                                                     0.079884
# don't stop - 2004 remaster                         fleetwood mac                                                          0.337696
# eastside (with halsey & khalid)                    benny blanco, halsey, khalid                                          -0.302533
# something about the way you look tonight - edit... elton john                                                             1.000000
# juke box hero                                      foreigner                                                              0.572633
# mercy                                              shawn mendes                                                           0.082096
# it's like that                                     run–d.m.c., jason nevins                                              -0.005826
# here without you                                   3 doors down                                                           0.179627
# listen to the band - single version                the monkees                                                            0.254709
# with a little luck - remastered 1993               wings                                                                  0.143202
# sing                                               ed sheeran                                                            -0.068665
# mississippi                                        pussycat                                                               0.185085
# flava                                              nathaniel                                                             -0.143876
# baby sittin' boogie - radio version                buzz clifford                                                          0.147069
# dr. love                                           tina charles                                                           0.039364
# landslide (glee cast version) (feat. gwyneth pa... glee cast, gwyneth paltrow                                             0.222217
#
# track_name                                                                      juke box hero  \
# artist_name                                                                         foreigner
# track_name                                         artist_name
# justified & ancient - stand by the jams            the klf                          -0.043722
# i know you want me (calle ocho)                    pitbull                          -0.124597
# from the bottom of my broken heart                 britney spears                   -0.279310
# apeman - 2014 remastered version                   the kinks                         0.020297
# you can't always get what you want                 the rolling stones                0.040025
# don't stop - 2004 remaster                         fleetwood mac                     0.459914
# eastside (with halsey & khalid)                    benny blanco, halsey, khalid     -0.208548
# something about the way you look tonight - edit... elton john                        0.572633
# juke box hero                                      foreigner                         1.000000
# mercy                                              shawn mendes                      0.292515
# it's like that                                     run–d.m.c., jason nevins         -0.059898
# here without you                                   3 doors down                      0.281734
# listen to the band - single version                the monkees                       0.511296
# with a little luck - remastered 1993               wings                             0.219191
# sing                                               ed sheeran                       -0.074809
# mississippi                                        pussycat                          0.197961
# flava                                              nathaniel                        -0.192022
# baby sittin' boogie - radio version                buzz clifford                     0.143306
# dr. love                                           tina charles                     -0.208266
# landslide (glee cast version) (feat. gwyneth pa... glee cast, gwyneth paltrow        0.081049
#
# track_name                                                                             mercy  \
# artist_name                                                                     shawn mendes
# track_name                                         artist_name
# justified & ancient - stand by the jams            the klf                         -0.107261
# i know you want me (calle ocho)                    pitbull                         -0.151043
# from the bottom of my broken heart                 britney spears                  -0.174026
# apeman - 2014 remastered version                   the kinks                       -0.116126
# you can't always get what you want                 the rolling stones              -0.467329
# don't stop - 2004 remaster                         fleetwood mac                    0.071861
# eastside (with halsey & khalid)                    benny blanco, halsey, khalid     0.214721
# something about the way you look tonight - edit... elton john                       0.082096
# juke box hero                                      foreigner                        0.292515
# mercy                                              shawn mendes                     1.000000
# it's like that                                     run–d.m.c., jason nevins        -0.085395
# here without you                                   3 doors down                     0.579614
# listen to the band - single version                the monkees                     -0.065748
# with a little luck - remastered 1993               wings                            0.124237
# sing                                               ed sheeran                       0.359066
# mississippi                                        pussycat                         0.086771
# flava                                              nathaniel                        0.117427
# baby sittin' boogie - radio version                buzz clifford                   -0.224056
# dr. love                                           tina charles                    -0.446382
# landslide (glee cast version) (feat. gwyneth pa... glee cast, gwyneth paltrow      -0.267446
#
# track_name                                                                       ...  \
# artist_name                                                                      ...
# track_name                                         artist_name                   ...
# justified & ancient - stand by the jams            the klf                       ...
# i know you want me (calle ocho)                    pitbull                       ...
# from the bottom of my broken heart                 britney spears                ...
# apeman - 2014 remastered version                   the kinks                     ...
# you can't always get what you want                 the rolling stones            ...
# don't stop - 2004 remaster                         fleetwood mac                 ...
# eastside (with halsey & khalid)                    benny blanco, halsey, khalid  ...
# something about the way you look tonight - edit... elton john                    ...
# juke box hero                                      foreigner                     ...
# mercy                                              shawn mendes                  ...
# it's like that                                     run–d.m.c., jason nevins      ...
# here without you                                   3 doors down                  ...
# listen to the band - single version                the monkees                   ...
# with a little luck - remastered 1993               wings                         ...
# sing                                               ed sheeran                    ...
# mississippi                                        pussycat                      ...
# flava                                              nathaniel                     ...
# baby sittin' boogie - radio version                buzz clifford                 ...
# dr. love                                           tina charles                  ...
# landslide (glee cast version) (feat. gwyneth pa... glee cast, gwyneth paltrow    ...
#
# track_name                                                                         asking  \
# artist_name                                                                         anwai
# track_name                                         artist_name
# justified & ancient - stand by the jams            the klf                       0.014658
# i know you want me (calle ocho)                    pitbull                      -0.413550
# from the bottom of my broken heart                 britney spears                0.319092
# apeman - 2014 remastered version                   the kinks                     0.182431
# you can't always get what you want                 the rolling stones            0.062638
# don't stop - 2004 remaster                         fleetwood mac                 0.071414
# eastside (with halsey & khalid)                    benny blanco, halsey, khalid  0.121783
# something about the way you look tonight - edit... elton john                    0.026530
# juke box hero                                      foreigner                    -0.052646
# mercy                                              shawn mendes                  0.096127
# it's like that                                     run–d.m.c., jason nevins     -0.119993
# here without you                                   3 doors down                  0.185609
# listen to the band - single version                the monkees                  -0.353712
# with a little luck - remastered 1993               wings                         0.196093
# sing                                               ed sheeran                   -0.105393
# mississippi                                        pussycat                      0.225032
# flava                                              nathaniel                    -0.321607
# baby sittin' boogie - radio version                buzz clifford                -0.088446
# dr. love                                           tina charles                 -0.181208
# landslide (glee cast version) (feat. gwyneth pa... glee cast, gwyneth paltrow   -0.083508
#
# track_name                                                                      u make me feel good  \
# artist_name                                                                              astronomyy
# track_name                                         artist_name
# justified & ancient - stand by the jams            the klf                                -0.099745
# i know you want me (calle ocho)                    pitbull                                 0.001094
# from the bottom of my broken heart                 britney spears                         -0.326875
# apeman - 2014 remastered version                   the kinks                              -0.248372
# you can't always get what you want                 the rolling stones                     -0.209617
# don't stop - 2004 remaster                         fleetwood mac                          -0.161969
# eastside (with halsey & khalid)                    benny blanco, halsey, khalid            0.061992
# something about the way you look tonight - edit... elton john                             -0.183297
# juke box hero                                      foreigner                              -0.251254
# mercy                                              shawn mendes                            0.014935
# it's like that                                     run–d.m.c., jason nevins                0.288620
# here without you                                   3 doors down                            0.108555
# listen to the band - single version                the monkees                            -0.188274
# with a little luck - remastered 1993               wings                                   0.285160
# sing                                               ed sheeran                              0.074516
# mississippi                                        pussycat                               -0.442936
# flava                                              nathaniel                               0.191705
# baby sittin' boogie - radio version                buzz clifford                          -0.485611
# dr. love                                           tina charles                            0.063731
# landslide (glee cast version) (feat. gwyneth pa... glee cast, gwyneth paltrow             -0.029264
#
# track_name                                                                      oh my love  \
# artist_name                                                                          layla
# track_name                                         artist_name
# justified & ancient - stand by the jams            the klf                       -0.128333
# i know you want me (calle ocho)                    pitbull                       -0.547755
# from the bottom of my broken heart                 britney spears                -0.116220
# apeman - 2014 remastered version                   the kinks                     -0.071425
# you can't always get what you want                 the rolling stones             0.226762
# don't stop - 2004 remaster                         fleetwood mac                 -0.192670
# eastside (with halsey & khalid)                    benny blanco, halsey, khalid   0.011752
# something about the way you look tonight - edit... elton john                     0.205101
# juke box hero                                      foreigner                      0.192587
# mercy                                              shawn mendes                   0.028822
# it's like that                                     run–d.m.c., jason nevins      -0.233965
# here without you                                   3 doors down                   0.171652
# listen to the band - single version                the monkees                    0.118646
# with a little luck - remastered 1993               wings                          0.220847
# sing                                               ed sheeran                    -0.360939
# mississippi                                        pussycat                       0.075109
# flava                                              nathaniel                     -0.614747
# baby sittin' boogie - radio version                buzz clifford                  0.409022
# dr. love                                           tina charles                  -0.234261
# landslide (glee cast version) (feat. gwyneth pa... glee cast, gwyneth paltrow     0.318232
#
# track_name                                                                        fragile  \
# artist_name                                                                         rozes
# track_name                                         artist_name
# justified & ancient - stand by the jams            the klf                       0.009586
# i know you want me (calle ocho)                    pitbull                      -0.202331
# from the bottom of my broken heart                 britney spears                0.198784
# apeman - 2014 remastered version                   the kinks                     0.068069
# you can't always get what you want                 the rolling stones            0.300161
# don't stop - 2004 remaster                         fleetwood mac                 0.059109
# eastside (with halsey & khalid)                    benny blanco, halsey, khalid  0.187000
# something about the way you look tonight - edit... elton john                    0.108874
# juke box hero                                      foreigner                    -0.033188
# mercy                                              shawn mendes                 -0.133621
# it's like that                                     run–d.m.c., jason nevins     -0.155051
# here without you                                   3 doors down                 -0.076476
# listen to the band - single version                the monkees                  -0.149449
# with a little luck - remastered 1993               wings                         0.018834
# sing                                               ed sheeran                   -0.221884
# mississippi                                        pussycat                     -0.007894
# flava                                              nathaniel                    -0.191978
# baby sittin' boogie - radio version                buzz clifford                -0.217146
# dr. love                                           tina charles                 -0.001644
# landslide (glee cast version) (feat. gwyneth pa... glee cast, gwyneth paltrow   -0.101978
#
# track_name                                                                      diamond child  \
# artist_name                                                                           aayushi
# track_name                                         artist_name
# justified & ancient - stand by the jams            the klf                          -0.003580
# i know you want me (calle ocho)                    pitbull                          -0.573887
# from the bottom of my broken heart                 britney spears                    0.185787
# apeman - 2014 remastered version                   the kinks                         0.162062
# you can't always get what you want                 the rolling stones                0.233105
# don't stop - 2004 remaster                         fleetwood mac                    -0.035786
# eastside (with halsey & khalid)                    benny blanco, halsey, khalid      0.193995
# something about the way you look tonight - edit... elton john                        0.089362
# juke box hero                                      foreigner                         0.052220
# mercy                                              shawn mendes                      0.083471
# it's like that                                     run–d.m.c., jason nevins         -0.252151
# here without you                                   3 doors down                      0.176910
# listen to the band - single version                the monkees                      -0.184591
# with a little luck - remastered 1993               wings                             0.201495
# sing                                               ed sheeran                       -0.285169
# mississippi                                        pussycat                          0.181707
# flava                                              nathaniel                        -0.520411
# baby sittin' boogie - radio version                buzz clifford                     0.085960
# dr. love                                           tina charles                     -0.253839
# landslide (glee cast version) (feat. gwyneth pa... glee cast, gwyneth paltrow       -0.096002
#
# track_name                                                                      i don't know  \
# artist_name                                                                            jon d
# track_name                                         artist_name
# justified & ancient - stand by the jams            the klf                         -0.204146
# i know you want me (calle ocho)                    pitbull                         -0.160449
# from the bottom of my broken heart                 britney spears                   0.247314
# apeman - 2014 remastered version                   the kinks                        0.194762
# you can't always get what you want                 the rolling stones               0.422188
# don't stop - 2004 remaster                         fleetwood mac                   -0.151387
# eastside (with halsey & khalid)                    benny blanco, halsey, khalid     0.131206
# something about the way you look tonight - edit... elton john                      -0.097224
# juke box hero                                      foreigner                       -0.344657
# mercy                                              shawn mendes                    -0.454605
# it's like that                                     run–d.m.c., jason nevins        -0.125227
# here without you                                   3 doors down                    -0.281895
# listen to the band - single version                the monkees                     -0.236835
# with a little luck - remastered 1993               wings                            0.241884
# sing                                               ed sheeran                      -0.150683
# mississippi                                        pussycat                        -0.184066
# flava                                              nathaniel                       -0.213140
# baby sittin' boogie - radio version                buzz clifford                    0.336415
# dr. love                                           tina charles                     0.257071
# landslide (glee cast version) (feat. gwyneth pa... glee cast, gwyneth paltrow       0.389429
#
# track_name                                                                      the answer  \
# artist_name                                                                      big words
# track_name                                         artist_name
# justified & ancient - stand by the jams            the klf                       -0.100321
# i know you want me (calle ocho)                    pitbull                        0.116614
# from the bottom of my broken heart                 britney spears                 0.044071
# apeman - 2014 remastered version                   the kinks                      0.181522
# you can't always get what you want                 the rolling stones             0.321965
# don't stop - 2004 remaster                         fleetwood mac                 -0.171010
# eastside (with halsey & khalid)                    benny blanco, halsey, khalid   0.351378
# something about the way you look tonight - edit... elton john                    -0.134084
# juke box hero                                      foreigner                     -0.188117
# mercy                                              shawn mendes                  -0.273064
# it's like that                                     run–d.m.c., jason nevins      -0.228508
# here without you                                   3 doors down                  -0.311449
# listen to the band - single version                the monkees                   -0.121582
# with a little luck - remastered 1993               wings                         -0.144810
# sing                                               ed sheeran                    -0.344031
# mississippi                                        pussycat                      -0.389045
# flava                                              nathaniel                     -0.157231
# baby sittin' boogie - radio version                buzz clifford                 -0.269324
# dr. love                                           tina charles                  -0.071428
# landslide (glee cast version) (feat. gwyneth pa... glee cast, gwyneth paltrow    -0.212709
#
# track_name                                                                             25.22  \
# artist_name                                                                     allan rayman
# track_name                                         artist_name
# justified & ancient - stand by the jams            the klf                          0.229376
# i know you want me (calle ocho)                    pitbull                         -0.082598
# from the bottom of my broken heart                 britney spears                  -0.054428
# apeman - 2014 remastered version                   the kinks                       -0.110481
# you can't always get what you want                 the rolling stones              -0.108560
# don't stop - 2004 remaster                         fleetwood mac                   -0.104056
# eastside (with halsey & khalid)                    benny blanco, halsey, khalid    -0.131969
# something about the way you look tonight - edit... elton john                       0.009002
# juke box hero                                      foreigner                        0.018107
# mercy                                              shawn mendes                    -0.027936
# it's like that                                     run–d.m.c., jason nevins         0.108211
# here without you                                   3 doors down                     0.138448
# listen to the band - single version                the monkees                      0.093983
# with a little luck - remastered 1993               wings                            0.172707
# sing                                               ed sheeran                      -0.288248
# mississippi                                        pussycat                         0.224694
# flava                                              nathaniel                       -0.418756
# baby sittin' boogie - radio version                buzz clifford                    0.018627
# dr. love                                           tina charles                    -0.035826
# landslide (glee cast version) (feat. gwyneth pa... glee cast, gwyneth paltrow       0.166924
#
# track_name                                                                      good feeling  \
# artist_name                                                                        jon jason
# track_name                                         artist_name
# justified & ancient - stand by the jams            the klf                          0.043675
# i know you want me (calle ocho)                    pitbull                         -0.384017
# from the bottom of my broken heart                 britney spears                  -0.153990
# apeman - 2014 remastered version                   the kinks                        0.093909
# you can't always get what you want                 the rolling stones               0.152307
# don't stop - 2004 remaster                         fleetwood mac                   -0.074398
# eastside (with halsey & khalid)                    benny blanco, halsey, khalid     0.115064
# something about the way you look tonight - edit... elton john                       0.121389
# juke box hero                                      foreigner                        0.069857
# mercy                                              shawn mendes                    -0.053727
# it's like that                                     run–d.m.c., jason nevins        -0.124198
# here without you                                   3 doors down                     0.110640
# listen to the band - single version                the monkees                      0.014315
# with a little luck - remastered 1993               wings                            0.392209
# sing                                               ed sheeran                      -0.373999
# mississippi                                        pussycat                         0.128033
# flava                                              nathaniel                       -0.596538
# baby sittin' boogie - radio version                buzz clifford                    0.295918
# dr. love                                           tina charles                     0.056543
# landslide (glee cast version) (feat. gwyneth pa... glee cast, gwyneth paltrow       0.159977
#
# track_name                                                                      cosmic angel - acoustic from capitol studios
# artist_name                                                                                                         grizfolk
# track_name                                         artist_name
# justified & ancient - stand by the jams            the klf                                                         -0.202693
# i know you want me (calle ocho)                    pitbull                                                         -0.277699
# from the bottom of my broken heart                 britney spears                                                  -0.120880
# apeman - 2014 remastered version                   the kinks                                                       -0.104046
# you can't always get what you want                 the rolling stones                                              -0.089550
# don't stop - 2004 remaster                         fleetwood mac                                                   -0.142797
# eastside (with halsey & khalid)                    benny blanco, halsey, khalid                                     0.258834
# something about the way you look tonight - edit... elton john                                                      -0.082695
# juke box hero                                      foreigner                                                       -0.097825
# mercy                                              shawn mendes                                                     0.255888
# it's like that                                     run–d.m.c., jason nevins                                        -0.165936
# here without you                                   3 doors down                                                     0.329043
# listen to the band - single version                the monkees                                                     -0.183165
# with a little luck - remastered 1993               wings                                                            0.333092
# sing                                               ed sheeran                                                       0.121660
# mississippi                                        pussycat                                                        -0.188383
# flava                                              nathaniel                                                        0.054663
# baby sittin' boogie - radio version                buzz clifford                                                   -0.164942
# dr. love                                           tina charles                                                    -0.160643
# landslide (glee cast version) (feat. gwyneth pa... glee cast, gwyneth paltrow                                       0.002155
#
# [20 rows x 40547 columns]

# %% [markdown]
# The following cell is for calculating cosine similarity score between two songs.
#
# For my presentation, I plan to briefly explain how cosine similarity works in the context of my project. Cosine similarity scores for the following songs are computed in pairwise order:
# - "diamonds" by rihanna
# - "mercy" by shawn mendes
# - "i gotta feeling" by black eyed peas
# - "hard times" by paramore

# %%
# Calculate cosine similarity score for two songs
track_sim[('diamonds', 'rihanna')][('hard times', 'paramore')]
# Out:
# 0.3539780760471589

# %% [markdown]
# ### 6. Create `recommend_songs` function given `track_name` and `artist_name`

# %% [markdown]
# The `recommend_songs` function is created to generate the top `n` song recommendations given a `track_name` and `artist_name`.

# %%
def recommend_songs(track_name, artist_name, n):
    """
    Get recommended songs based on track_name and artist_name using a similarity DataFrame.

    Parameters:
    - track_name (str): Name of the track to search for.
    - artist_name (str): Name of the artist associated with the track.
    - track_sim_df (pd.DataFrame): DataFrame containing the similarity scores with MultiIndex.

    Returns:
    - pd.Series: Series containing top recommended songs based on similarity scores.
    """

    sim_df = track_sim

    try:
        # Use loc to retrieve data based on MultiIndex values
        result = sim_df.loc[(track_name, artist_name)]

        # Sort the MultiIndex levels lexically
        result_sorted = result.sort_index()

        # Drop the specified track_name from the MultiIndex DataFrame
        result_dropped = result_sorted.drop(track_name, level="track_name")

        # Sort the resulting DataFrame (if needed) and retrieve top values
        top_values = result_dropped.sort_values(ascending=False).head(n)

        return top_values

    except KeyError:
        print(f"No recommendation found for '{track_name}' by '{artist_name}'")
        return pd.Series([])  # Return an empty Series if no recommendation is found

# %% [markdown]
# ##### Sample outputs for `recommend_songs`

# %%
# Call the function with specific track_name and artist_name
recommend_songs('levitating', 'dua lipa', 10)
# Out:
# track_name                               artist_name
# dreams                                   dua lipa              0.930893
# never gonna not dance again              p!nk                  0.923524
# tv in the morning                        dnce                  0.892390
# give it 2 me                             madonna               0.878239
# the way                                  ariana grande         0.862144
# finesse                                  bruno mars            0.861334
# don't hold your breath                   nicole scherzinger    0.860264
# dance the night (from barbie the album)  dua lipa              0.860172
# like i love you                          justin timberlake     0.856917
# bang bang bang - russ chimes remix       mark ronson           0.856188
# Name: (levitating, dua lipa), dtype: float64

# %%
# Call the function with specific track_name and artist_name
recommend_songs('sorry', 'justin bieber', 10)
# Out:
# track_name                                artist_name
# sorry - latino remix                      justin bieber       0.986271
# what's hatnin'                            justin bieber       0.890373
# we can't stop                             miley cyrus         0.855894
# love myself                               hailee steinfeld    0.829388
# last time                                 labrinth            0.824754
# roller coaster                            justin bieber       0.820546
# hymn for the weekend - seeb remix         coldplay            0.807104
# company                                   justin bieber       0.805850
# 2002                                      anne-marie          0.803936
# liquor store blues (feat. damian marley)  bruno mars          0.799498
# Name: (sorry, justin bieber), dtype: float64

# %%
# Call the function with specific track_name and artist_name
recommend_songs('a thousand miles', 'vanessa carlton', 10)
# Out:
# track_name                       artist_name
# something to sleep to            michelle branch             0.818109
# where are you now?               michelle branch             0.761893
# don't speak liar                 we the kings                0.757283
# shattered [turn the car around]  o.a.r.                      0.754293
# how to save a life               the fray                    0.749018
# goodbye to you                   michelle branch             0.749015
# hurricane                        the fray                    0.732766
# she's so high                    tal bachman                 0.723493
# there she goes                   sixpence none the richer    0.722743
# breathe your name                sixpence none the richer    0.718964
# Name: (a thousand miles, vanessa carlton), dtype: float64

# %%
# Call the function with specific track_name and artist_name
recommend_songs('hello', 'adele', 10)
# Out:
# track_name                                artist_name
# pray                                      sam smith                     0.848638
# turning tables                            adele                         0.808146
# love in the dark                          adele                         0.799982
# run                                       leona lewis                   0.756665
# half the man                              rozzi crane                   0.751191
# one and only                              adele                         0.744689
# send my love (to your new lover)          adele                         0.743433
# met him last night (feat. ariana grande)  demi lovato, ariana grande    0.734106
# water and a flame (feat. adele)           daniel merriweather, adele    0.725639
# hometown glory                            adele                         0.724806
# Name: (hello, adele), dtype: float64

# %%
# Call the function with specific track_name and artist_name
recommend_songs('fuel', 'metallica', 10)
# Out:
# track_name                                 artist_name
# for whom the bell tolls - remastered       metallica      0.885263
# from the pinnacle to the pit               ghost b.c.     0.857714
# shout at the devil                         mötley crüe    0.805559
# sad but true                               metallica      0.779839
# jigolo har megiddo                         ghost b.c.     0.779290
# looks that kill                            mötley crüe    0.767522
# aces high - 1998 remastered version        iron maiden    0.756359
# unskinny bop                               poison         0.751943
# hero of the day                            metallica      0.744439
# hot for teacher - 2015 remastered version  van halen      0.736229
# Name: (fuel, metallica), dtype: float64

# %%
# Call the function with specific track_name and artist_name
recommend_songs('run to the hills', 'iron maiden', 10)
# Out:
# track_name                                  artist_name
# run to the hills - 1998 remastered version  iron maiden                    0.998652
# aces high - 1998 remastered version         iron maiden                    0.928692
# beautiful girls                             van halen                      0.874457
# this is how i disappear                     my chemical romance            0.816112
# young lovers go pop!                        this many boyfriends           0.815596
# i don't love you                            my chemical romance            0.815417
# crimson and clover                          joan jett & the blackhearts    0.813686
# this time around                            hanson                         0.812910
# solutions                                   the sundance kids              0.811164
# i remember                                  bully                          0.807057
# Name: (run to the hills, iron maiden), dtype: float64

# %%
# Call the function with specific track_name and artist_name
recommend_songs('supermodel', 'sza', 10)
# Out:
# track_name                                   artist_name
# the need to know (feat. sza)                 wale                                0.821436
# love yourself                                justin bieber                       0.809226
# wake me up                                   ed sheeran                          0.803931
# contacts                                     brockhampton                        0.800422
# heaven - a cappella feat. pusha t of clipse  john legend                         0.799732
# cold blood                                   bruno major                         0.788056
# 20 something                                 sza                                 0.782156
# i'm not that smart                           original broadway cast recording    0.774694
# lil tokyo                                    gnash                               0.774673
# runnin' - interlude                          kehlani                             0.769629
# Name: (supermodel, sza), dtype: float64

# %% [markdown]
# ### 7. Create `generate_personalised_playlist` function using the `recommend_songs` function

# %% [markdown]
# The `generate_personalised_playlist` function creates a 15-track playlist based on the songs selected in the randomly generated tracklist (from `generate_random_tracks_balanced`).
#
# 15 songs is a good length for the first playlist as it is not too short and not too long. 15 songs usually take about 50 to 55 minutes to complete from start to finish which is suitable for the users who volunteered to take part in the study.

# %%
def generate_personalised_playlist(input_indices, tracks_dict):
    # Instantiate an empty data frame to store the tracks
    playlist = pd.DataFrame()

    # For each song selected from the randomly generated list,
    # the top 5 recommended songs will be added into the `playlist` df
    for i in input_indices:
        track = tracks_dict[i][0]
        artist = tracks_dict[i][1]
        top5songs = recommend_songs(track, artist, 5)
        playlist = pd.concat([playlist, top5songs], ignore_index=False)
    
    # Convert (track_name, artist_name) from the df to a list of tuples
    tuple_list = list(playlist.index)

    # Create a DataFrame from the list of tuples
    # If playlist contains more than 15 songs, the 15 songs chosen in the final playlist will be randomly sampled
    # If less than 3 songs are selected, an error message will be shown
    if len(tuple_list) < 15:
        print("Choose at least 3 songs!")
    else:
        tuple_list_subset = random.sample(tuple_list, 15)
        df = pd.DataFrame(tuple_list_subset, columns=['track_name', 'artist_name'])
        return df

# %% [markdown]
# ##### Create `df_to_tuples` function for data pre-processing

# %% [markdown]
# The function `df_to_tuples` returns a list of tuples as output for easier pre-processing when creating the actual Spotify playlist.

# %%
def df_to_tuples(personalised_playlist):
    # Convert to list of tuples
    track_artist_tuples = [(row['track_name'], row['artist_name']) for _, row in personalised_playlist.iterrows()]
    return track_artist_tuples

# %% [markdown]
# ### 8. Set up Spotify API credentials for playlist generation

# %% [markdown]
# The following cell creates a temporary HTTP server on localhost with a random port number (port 0 means that the operating system will assign a free port). It then retrieves the assigned port number and closes the temporary server. This is a workaround to get a free port number, which is required for the Spotify authentication flow.
#
# I created a Spotify Developer account to obtain my personal `CLIENT_ID` and `CLIENT_SECRET`. These Spotify application credentials are required for authentication with Spotify Web API.
#
# Finally, the redirect URI (http://example.com/callback) is the one that Spotify will use to redirect the user after the authentication process.

# %% [markdown]
# Note: Replace `CLIENT_ID` and `CLIENT_SECRET` with your own Spotify Developer credentials.

# %%
# Create a temporary HTTP server to get the assigned port
temp_server = HTTPServer(('localhost', 0), BaseHTTPRequestHandler)
port = temp_server.server_address[1]
temp_server.server_close()

# Replace these with your own Spotify credentials
CLIENT_ID = 'replace'
CLIENT_SECRET = 'replace'

# Update the REDIRECT_URI with the assigned port
REDIRECT_URI = f'http://example.com/callback'

# %% [markdown]
# The following cell uses the `spotipy` library, which is a lightweight Python library for the Spotify Web API.
#
# This line initialises the `spotipy.Spotify` client with an authentication manager (`SpotifyOAuth`). The `SpotifyOAuth` object is initialised with my Spotify application credentials, the redirect URI, and the desired scope (`playlist-modify-public` in this case, which allows the application to modify public playlists).
#
# After executing this code, the `sp` object will be authenticated with Spotify, and I can use it to interact with the Spotify Web API, such as fetching data, creating playlists, or adding tracks to playlists.

# %%
# Authenticate with Spotify
sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id=CLIENT_ID,
                                               client_secret=CLIENT_SECRET,
                                               redirect_uri=REDIRECT_URI,
                                               scope="playlist-modify-public"))

# %% [markdown]
# ##### Create `generate_spotify_playlist` function to generate actual playlist

# %% [markdown]
# The `generate_spotify_playlist` is the final and most important function in this notebook which creates the actual personalised playlist on Spotify, using the Spotify Web API.
#
# The entire process from selecting at least 3 genres to creating the actual playlist on Spotify could take less than 10 minutes.
#
# This facilitates the conduct of my user studies which would allow me to gather data to evaluate the performance of the recommender, as well as useful observations and feedback to make certain adjustments to improve the recommender.

# %%
def generate_spotify_playlist(tracklist, creator):
    # Example list of (track_name, artist_name) tuples
    track_artist_tuples = df_to_tuples(tracklist)

    # Create lists to store the track names and artist names
    track_names = []
    artist_names = []

    # Iterate over the tuples and append the track names and artist names to the respective lists
    for track_name, artist_name in track_artist_tuples:
        track_names.append(track_name)
        artist_names.append(artist_name)

    # Create a DataFrame to store the track and artist information
    tracks_40k_df = pd.DataFrame({'track_name': track_names, 'artist_name': artist_names})

    # Create an empty list to store the track URIs
    track_uris = []

    # Search for each track and add its URI to the list
    for index, row in tracks_40k_df.iterrows():
        track_name = row['track_name']
        artist_name = row['artist_name']
        query = f'track:{track_name} artist:{artist_name}'
        results = sp.search(q=query, type='track', limit=1)

        if results['tracks']['items']:
            track_uri = results['tracks']['items'][0]['uri']
            track_uris.append(track_uri)
        else:
            print(f"No track found for '{track_name}' by '{artist_name}'")

    # Create a new playlist
    user_id = sp.current_user()['id']
    playlist_name = f"{creator}'s Playlist"
    playlist_description = f"A custom playlist for {creator}"
    playlist = sp.user_playlist_create(user=user_id,
                                    name=playlist_name,
                                    public=True,
                                    description=playlist_description)

    # Add the tracks to the new playlist
    sp.playlist_add_items(playlist_id=playlist['id'], items=track_uris)
    print(f"{creator}'s Playlist created successfully with {len(track_uris)} tracks.")

# %% [markdown]
# ---

# %% [markdown]
# ### User Studies

# %% [markdown]
# This section is used primarily to conduct the user studies.
#
# The following three steps are performed for each user:
# 1. Choose at least 3 genres to generate a random list of 15 tracks
# 2. Choose at least 3 songs to generate your own personalised playlist
# 3. Generate the playlist on Spotify
#
# Each user is then requested to listen to their personalised playlist and evaluate each song on a scale of 1 to 10, where:
# - 0 - i do not like the song at all
# - 5 - neutral
# - 10 - i like the song a lot
#
# A percentage score is then computed for each playlist.

# %% [markdown]
# ##### Step 1: Choose at least 3 genres to generate a random list of 15 tracks

# %%
# Common genres to choose from
# This list is not fed into any functions and is purely for display purposes
common_genres = ['pop',
                 'rock',
                 'hip hop',
                 'rap',
                 'r&b',
                 'soul',
                 'disco',
                 'edm',
                 'house',
                 'metal',
                 'punk',
                 'country',
                 'folk',
                 'singer-songwriter',
                 'jazz']

# %%
# This step was eventually removed
# Choose sub-genres (optional)
# top_subgenres(common_genres)

# %%
# Specify genres and number of random track pairs to generate
selected_genres = ['dance pop', 'disco', 'pop']

# Generate random track pairs based on the specified genres
random_tracks_by_genre = generate_random_tracks_balanced(selected_genres)
track_viewer(random_tracks_by_genre)
# Out:
#                                                      track_name  \
# track_number
# 1                                            jump (for my love)
# 2                                                chain reaction
# 3                                              larger than life
# 4                                     hear my name - radio edit
# 5                                             tellin' everybody
# 6                                                    high on me
# 7                                       the creeps (radio edit)
# 8                                         drop it like it's hot
# 9                                    have you never been mellow
# 10                                                       jolene
# 11                                     kiss me more (feat. sza)
# 12                              take me home (feat. bebe rexha)
# 13            calling all hearts (feat. robin thicke & jessi...
# 14                                girls on film - 2010 remaster
# 15                                              love on display
#
#                                      artist_name  \
# track_number
# 1                            the pointer sisters
# 2                                     diana ross
# 3                                backstreet boys
# 4                              armand van helden
# 5                                   human nature
# 6                                  guy sebastian
# 7                  camille jones, fedde le grand
# 8                  snoop dogg, pharrell williams
# 9                             olivia newton-john
# 10                            olivia newton-john
# 11                                 doja cat, sza
# 12                         cash cash, bebe rexha
# 13            dj cassidy, robin thicke, jessie j
# 14                                   duran duran
# 15                                 guy sebastian
#
#                                                   artist_genres
# track_number
# 1             disco, girl group, hi-nrg, motown, new wave po...
# 2             adult standards, disco, motown, quiet storm, s...
# 3                                      boy band, dance pop, pop
# 4             big beat, deep house, disco house, house, spee...
# 5                     australian pop, australian rock, boy band
# 6                        australian pop, australian talent show
# 7             dutch house, edm, electro house, house, pop da...
# 8             g funk, gangster rap, hip hop, pop rap, rap, w...
# 9             adult standards, australian dance, disco, mell...
# 10            adult standards, australian dance, disco, mell...
# 11                                dance pop, pop, pop, r&b, rap
# 12            dance pop, edm, electro house, electropowerpop...
# 13            dance pop, neo soul, pop rap, r&b, urban conte...
# 14            album rock, dance rock, new romantic, new wave...
# 15                       australian pop, australian talent show

# %% [markdown]
# ##### Step 2: Choose at least 3 songs to generate your own personalised playlist

# %%
# With reference to the random song list generated in Step 1
# Input the track_number of at least 3 songs (thank you like) from the list above
preferred_tracks_index = [3,4,14]
preferred_tracks = generate_personalised_playlist(preferred_tracks_index, random_tracks_by_genre)
preferred_tracks
# Out:
#                                            track_name  \
# 0                                      hearts on fire
# 1   here comes santa claus (right down santa claus...
# 2                                crying in the chapel
# 3                                     hot in the city
# 4                                       same old girl
# 5                                         come undone
# 6   you don't know me (feat. duane harden) - radio...
# 7                                               piano
# 8                                      christmas time
# 9                           put your hand in the hand
# 10                  is there something i should know?
# 11                      rio - 2009 remastered version
# 12                       last friday night (t.g.i.f.)
# 13                                   a view to a kill
# 14                                    family portrait
#
#                         artist_name
# 0                     randy meisner
# 1                      mariah carey
# 2                    peter blakeley
# 3                        billy idol
# 4                     darryl cotton
# 5                       duran duran
# 6   armand van helden, duane harden
# 7                     ariana grande
# 8                christina aguilera
# 9                             ocean
# 10                      duran duran
# 11                      duran duran
# 12                       katy perry
# 13                      duran duran
# 14                             p!nk

# %% [markdown]
# ##### Step 3: Generate the playlist on Spotify

# %%
# Replace the string with the user's name
# generate_spotify_playlist(preferred_tracks, "Syahiran")

# %% [markdown]
# ---

# %% [markdown]
# ### Summary of Results

# %% [markdown]
# As I interviewed more users, I made incremental changes to the recommender system in a bid to improve the overall enjoyability score (calculated as the average percentage score of the user's song ratings).
#
# Altogether, there were 5 different versions and each version was tested on a different group of users. The following table describes the base model (V1) and the incremental changes that were made for subsequent versions.
#
# | Version | Description |
# |-------------------------------|-------------|
# | V1 (base) | 1. User selects at least 3 preferred songs from the random list <br> 2. The recommender gives the top 10 similar songs for each song <br> 3. 15 songs are sampled to form the playlist |
# | V2 | The recommender now gives the top 5 similar songs for each song, instead of 10 |
# | V3 | The random song generator and song recommender now pull from the 40k songs data set, instead of the 10k songs data set |
# | V4 | The random song generator now pulls from the 10k songs data set (as in V1 and V2), while the song recommender pulls from the 40k songs data set (as in V3) |
# | V5 | The random song generator shows a balanced sample of songs for each genre that the user selects |

# %% [markdown]
# The following table displays the summary of results from the user studies. The percentage scores shown represent the average user ratings for each version of the recommender.
#
# | Version | No. of Participants | Average Score |
# |-------------|-------------|-------------|
# | V1 (base) | 7 | 62.0% |
# | V2 | 7 |61.9% |
# | V3 | 2 |72.0% |
# | V4 | 6 |68.9% |
# | V5 | 8 |66.0% |

# %% [markdown]
# ### Evaluation

# %% [markdown]
# The base recommender (V1) started off strong with an average score of 62%. I made a slight tweak for V2 where only the top 5 songs (instead of the top 10 songs) based on similarity scores would be considered for the playlist before random sampling the final 15 songs. With this change, the average score remained largely unaffected. However, from V1 and V2, there were two participants whose average scores are below 45% (specifically, 37.3% and 44.7%). One common point I observed for these two users is that their selected genres are less mainstream, for example: "indie folk", "electronica" and "metal." Upon further study, I chose two metal songs to test the song recommender and found that the top 5 recommended songs for each of these songs included pop songs by Lady Gaga and Sia.
#
# With V3, my goal was to improve the recommendations for less popular/mainstream genres. This is why I found a larger data set (with a wider range of songs) to supplement the 10k data set (which contained songs that had charted and hence were generally more popular). While V3 appears to have the highest average score amongst the different versions, I only used V3 on two participants as drawing from the larger 40k data set to generate songs randomly based on genre resulted in users not being able to recognise most of the songs generated. This meant that the random list of songs had to be refreshed more than 5 times before users could see songs that they like or recognise, which impacted the user experience quite greatly. This prompted me to revert to the earlier version of the random song generator, which draws from the smaller 10k data set, for V4 (the song recommender still draws from the 40k data set as in V3). With the smaller data set, users typically need less than 3 refreshes to recognise at least 3 songs from the random list generated, resulting in a better user experience.
#
# After conducting studies on six participants for V4, I found that the results were mainly positive with only one participant having an average score below 60% (specifically, 59.3%). One possible reason why this user did not enjoy her playlist as much is because the songs in her playlist were mainly "pop" even though she had chosen two other (less popular) genres, "contemporary r&b" and "indie pop." The reason for this is that the random list generated was overpopulated by "pop" songs. In a bid to improve the user experience further, I decided to tweak the random song generator to allow each of the user's selected genres to be represented evenly. This meant that popular genres such as "pop", "rock" and "hip hop" will not "overpower" other less popular genres in the random song list, if a user selects a mix of popular and less popular genres. The goal is to have the playlist be representative of the user's music taste overall, instead of having it be skewed to one popular genre.

# %% [markdown]
# ### Recommendations

# %% [markdown]
# For further development of this recommender system, I suggest exploring the following two approaches:
#
# 1. **A hybrid approach consisting of collaborative filtering and content-based filtering techniques** <br>
# - Content-based filtering (current approach)
#     - Currently, the song recommender employs the content-based collaborative filtering technique using cosine similarity.
#     - Uses characteristics such as genre, artist, energy, danceability, acousticness etc. to measure similarity between songs.
#     - Recommends songs that are similar to the ones the user has previously liked or consumed, based on their content or metadata.
#     - Does not consider preferences or behavior of other users; recommendations are based solely on the user's own preferences and the item's content.
# - Collaborative filtering (supplementary approach)
#     - Since each user was asked to rate each song on their personalised playlist from 0 to 10 as part of the user studies, we may have sufficient preference data to start implementing collaborative filtering techniques.
#         1. Item-based collaborative filtering:
#             - This approach recommends songs that are similar to the ones the user has previously liked, based on the preferences and behavior of other users.
#             - It analyses the patterns of songs that users have listened to, and recommends songs that are similar to the ones a user has enjoyed.
#             - Measures similarity between items based on the preferences and behavior of other users, rather than the content or attributes of the items themselves.
#         2. User-based collaborative filtering:
#             - This approach recommends songs based on the preferences of other users with similar tastes.
#             - It analyses the behavior and preferences of users to find similarities between them and recommend songs that similar users have liked.
#             - Does not consider the content or attributes of the items themselves; recommendations are based solely on the preferences of similar users.
#
# - In practice, hybrid approaches that combine user-based collaborative filtering, item-based filtering, and content-based filtering are often used to leverage the strengths of each technique and mitigate their weaknesses.
#
# 2. **Deep learning or matrix factorisation to determine track genres** <br>
# - One major drawback in the Spotify API is that we are unable to extract the track genres, only the artist genres and album artist album genres.
# - Upon further reading online, it seems like many tracks on Spotify don't even have genres assigned to them, unlike on Apple Music.
# - Let's consider the following edge case from one of my user studies:
#     - A user selects the genres "pop, punk, singer-songwriter" to generate random tracks, and the song "Side to Side" by "Ariana Grande and Nicki Minaj" is shown as one of the songs.
#     - While the song is largely considered a "pop" song as Ariana Grande is the main artist, the "artist genres" metadata attached to the song reads "pop, hip pop, pop, queens hip hop, rap."
#     - The user selects "Side to Side" alongside two other songs to feed into the recommender.
#     - The user's personalised playlist eventually included rap songs even though she had not selected "rap" as one of her preferred genres, and did not select any "rap" songs from the random list.
#     - My inference is that this happened as a result of the "rap" genre (assigned to Nicki Minaj) being attached to the song "Side to Side" (each track's 'artist_genres' was one hot encoded before performing cosine similarity).
# - While the above case is rare, it could happen if multiple different genres are assigned to the same song, especially when it comes to artist collaborations. If artists X and Y were to collaborate on the same track, a user may like a song because of artist X and not necessarily artist Y. However, the current recommender would still be able to recommend songs similar to artist Y.
# - A possible workaround is to experiment with deep learning and/or matrix factorisation.
#     - Deep learning:
#         - Neural networks and deep learning techniques, such as autoencoders, recurrent neural networks (RNNs), and convolutional neural networks (CNNs), can be used to learn complex patterns and representations from user data and song features to determine the genre(s) of each song and generate accurate, personalised recommendations.
#     - Matrix factorisation:
#         - This technique is often used in collaborative filtering systems. It decomposes the user-item rating matrix into lower-dimensional matrices, capturing latent factors that represent user preferences and item characteristics. These latent factors can be used to predict missing ratings (in this case, track genres) and generate recommendations.
